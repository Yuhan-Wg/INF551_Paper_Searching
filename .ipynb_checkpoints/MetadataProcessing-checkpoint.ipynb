# %%
import json
import re
import nltk
import requests
from nltk.corpus import stopwords

# %%
with open("../data/json/textList.json",'r',encoding='utf-8') as json_file:
    p = json.load(json_file)

# %%
p['2018'].keys()
# Out:
# dict_keys(['Jan 05', 'Jan 19', 'Jan 26', 'Feb 02', 'Feb 09', 'Feb 16', 'Feb 23', 'Mar 02', 'Mar 09', 'Mar 16', 'Mar 23', 'Mar 30', 'Apr 06', 'Apr 13', 'Apr 20', 'Apr 27', 'May 04', 'May 11', 'May 18', 'May 25', 'Jun 01', 'Jun 08', 'Jun 15', 'Jun 22', 'Jun 29', 'Jul 06', 'Jul 13', 'Jul 20', 'Jul 27', 'Aug 03', 'Aug 10', 'Aug 17', 'Aug 24', 'Aug 31', 'Sep 07', 'Sep 14', 'Sep 21', 'Sep 28', 'Oct 05', 'Jan 12'])

# %%
papers = []
idx = 0
for year in p:
    for week in p[year]:
        for paper in p[year][week]:
            paper['id'] = idx
            idx+=1
            papers.append(paper)

# %%
len(papers)
# Out:
# 3955

# %%
#  'title', 'author', 'authorInstitution', 'publisher', 
#  'text'
papers[1].keys()
# Out:
# dict_keys(['category', 'type', 'title', 'author', 'authorInstitution', 'publisher', 'date', 'doi', 'textLink', 'pptLink', 'imageLink', 'text', 'pdfLink', 'id'])

# %%
json_index = {}

# %%
categorys = []
json_index['category'] = {}
for paper in papers:
    if paper['category']:
        paper['category'] = paper['category'].replace('\n',' ').replace('\t','').replace('&amp; ','').replace('.','')
    else:
        paper['category'] = 'None'
    if paper['category'] in json_index['category']:
        json_index['category'][paper['category']].append(paper['id'])
    else:
        json_index['category'][paper['category']] = [paper['id']]
    categorys.append(paper['category'])

# %%
cate_set = set(categorys)

# %%
cate_set
# Out:
# {'Articles',
#  'Association Affairs',
#  'Books',
#  'Books et al.',
#  'Brevia',
#  'Editorial',
#  "Editors' Choice",
#  'Education Forum',
#  'Essays',
#  'Essays on Science and Society',
#  'Feature',
#  'In Brief',
#  'In Depth',
#  'Introduction to Special Issue',
#  'Introduction to special issue',
#  'Letters',
#  'News',
#  'News Analysis',
#  'News Focus',
#  'News of the Week',
#  None,
#  'Perspective',
#  'Perspectives',
#  'Policy Forum',
#  'Products Materials',
#  'Report',
#  'Reports',
#  'Research Article',
#  'Research Articles',
#  'Retraction',
#  'Review',
#  'Reviews',
#  'Special Issue Reports',
#  'Special Issue Research Articles',
#  'Technical Comments',
#  'This Week in Science',
#  'Working Life'}

# %%
re.sub('[^a-zA-Z0-9 ]','','This Week in\n\t\t\t\t\t\t\t\tScience'.replace('\n',' '))
# Out:
# 'This Week in Science'

# %%
'This Week in\n\t\t\t\t\t\t\t\tScience'.replace('\n',' ').replace('\t','')
# Out:
# 'This Week in Science'

# %%
json_index['category'].keys()
# Out:
# dict_keys(['None', 'News of the Week', 'Letters', 'Books et al.', 'Perspective', 'Research Article', 'Report', 'News Focus', 'Policy Forum', 'Brevia', 'Review', 'Technical Comments', 'News', 'Association Affairs', 'Education Forum', 'Introduction to special issue', 'Retraction', 'Essays on Science and Society', 'News Analysis', 'Perspectives', 'Articles', 'Books', 'In Brief', 'In Depth', 'Feature', 'Working Life', 'Research Articles', 'Special Issue Reports', 'Special Issue Research Articles', 'Reports', "Editors' Choice", 'Editorial', 'Reviews', 'This Week in Science', 'Products Materials', 'Essays', 'Introduction to Special Issue'])

# %%
typel = []
n = 0
for paper in papers:
    #if paper['type']:
        #paper['type'] = paper['category'].replace('\n',' ').replace('\t','').replace('&amp; ','')
    typel.append(paper['type'])
    if not paper['type']: n+=1

# %%
set(typel)
# Out:
# {'Article Commentary',
#  'Book Review',
#  'Brief Report',
#  'Correction',
#  'Editorial',
#  'Introduction',
#  'Letter',
#  'News',
#  None,
#  'Obituary',
#  'Other',
#  'Reply',
#  'Research Article',
#  'Retraction',
#  'Review Article'}

# %%
lists = []
s = 'type'
json_index[s] = {}
for paper in papers:
    if paper[s]:
        paper[s] = paper[s]
    else:
        paper[s] = 'None'
    if paper[s] in json_index[s]:
        json_index[s][paper[s]].append(paper['id'])
    else:
        json_index[s][paper[s]] = [paper['id']]
    lists.append(paper[s])

# %%
json_index[s]
# Out:
# {'Other': [0,
#   17,
#   33,
#   57,
#   70,
#   118,
#   123,
#   148,
#   155,
#   163,
#   180,
#   200,
#   215,
#   216,
#   250,
#   284,
#   286,
#   299,
#   310,
#   345,
#   357,
#   389,
#   395,
#   456,
#   465,
#   490,
#   493,
#   503,
#   512,
#   516,
#   517,
#   520,
#   521,
#   528,
#   540,
#   541,
#   559,
#   564,
#   600,
#   620,
#   651,
#   657,
#   735,
#   742,
#   760,
#   763,
#   777,
#   784,
#   817,
#   833,
#   846,
#   855,
#   876,
#   879,
#   913,
#   921,
#   952,
#   982,
#   988,
#   999,
#   1029,
#   1035,
#   1062,
#   1092,
#   1112,
#   1116,
#   1133,
#   1156,
#   1162,
#   1213,
#   1233,
#   1234,
#   1239,
#   1260,
#   1266,
#   1316,
#   1348,
#   1349,
#   1353,
#   1355,
#   1362,
#   1393,
#   1394,
#   1405,
#   1415,
#   1422,
#   1445,
#   1451,
#   1457,
#   1471,
#   1480,
#   1486,
#   1494,
#   1500,
#   1515,
#   1525,
#   1565,
#   1585,
#   1603,
#   1611,
#   1627,
#   1647,
#   1655,
#   1688,
#   1716,
#   1724,
#   1732,
#   1758,
#   1786,
#   1793,
#   1860,
#   1878,
#   1887,
#   1904,
#   1914,
#   1932,
#   1955,
#   1970,
#   1978,
#   1992,
#   2016,
#   2056,
#   2060,
#   2078,
#   2135,
#   2139,
#   2152,
#   2167,
#   2170,
#   2182,
#   2187,
#   2207,
#   2235,
#   2239,
#   2273,
#   2281,
#   2318,
#   2322,
#   2389,
#   2439,
#   2442,
#   2480,
#   2492,
#   2494,
#   2495,
#   2507,
#   2516,
#   2518,
#   2535,
#   2541,
#   2551,
#   2552,
#   2561,
#   2579,
#   2600,
#   2605,
#   2625,
#   2631,
#   2632,
#   2644,
#   2649,
#   2701,
#   2702,
#   2708,
#   2709,
#   2728,
#   2757,
#   2760,
#   2796,
#   2851,
#   2859,
#   2867,
#   2956,
#   2990,
#   3029,
#   3035,
#   3051,
#   3084,
#   3116,
#   3129,
#   3141,
#   3142,
#   3147,
#   3158,
#   3182,
#   3187,
#   3200,
#   3238,
#   3252,
#   3258,
#   3307,
#   3308,
#   3333,
#   3334,
#   3335,
#   3381,
#   3412,
#   3442,
#   3447,
#   3450,
#   3455,
#   3461,
#   3476,
#   3485,
#   3493,
#   3527,
#   3531,
#   3555,
#   3562,
#   3581,
#   3602,
#   3620,
#   3634,
#   3656,
#   3711,
#   3714,
#   3728,
#   3756,
#   3760,
#   3772,
#   3785,
#   3794,
#   3807,
#   3813,
#   3819,
#   3827,
#   3849,
#   3855,
#   3859,
#   3901,
#   3930,
#   3936],
#  'News': [1,
#   2,
#   13,
#   14,
#   15,
#   24,
#   25,
#   31,
#   32,
#   38,
#   39,
#   45,
#   58,
#   59,
#   60,
#   61,
#   71,
#   72,
#   74,
#   80,
#   81,
#   82,
#   83,
#   84,
#   85,
#   87,
#   93,
#   101,
#   102,
#   103,
#   107,
#   114,
#   126,
#   127,
#   129,
#   130,
#   131,
#   137,
#   138,
#   145,
#   146,
#   147,
#   156,
#   157,
#   158,
#   164,
#   169,
#   175,
#   176,
#   177,
#   178,
#   184,
#   195,
#   213,
#   221,
#   222,
#   224,
#   225,
#   235,
#   236,
#   237,
#   239,
#   254,
#   255,
#   261,
#   262,
#   271,
#   281,
#   282,
#   291,
#   296,
#   306,
#   307,
#   308,
#   320,
#   321,
#   322,
#   332,
#   338,
#   339,
#   340,
#   341,
#   348,
#   349,
#   350,
#   354,
#   355,
#   356,
#   366,
#   367,
#   370,
#   371,
#   373,
#   374,
#   383,
#   384,
#   385,
#   396,
#   411,
#   412,
#   420,
#   421,
#   422,
#   424,
#   425,
#   433,
#   434,
#   435,
#   436,
#   437,
#   444,
#   445,
#   453,
#   454,
#   457,
#   466,
#   467,
#   468,
#   469,
#   488,
#   489,
#   494,
#   495,
#   501,
#   513,
#   514,
#   523,
#   524,
#   525,
#   526,
#   527,
#   536,
#   537,
#   538,
#   560,
#   561,
#   562,
#   571,
#   573,
#   575,
#   576,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   593,
#   595,
#   596,
#   597,
#   598,
#   606,
#   607,
#   608,
#   609,
#   615,
#   616,
#   617,
#   621,
#   622,
#   623,
#   630,
#   640,
#   641,
#   648,
#   649,
#   658,
#   659,
#   666,
#   667,
#   668,
#   674,
#   701,
#   702,
#   703,
#   704,
#   720,
#   721,
#   722,
#   728,
#   729,
#   730,
#   732,
#   733,
#   738,
#   740,
#   741,
#   752,
#   758,
#   774,
#   775,
#   778,
#   785,
#   786,
#   791,
#   792,
#   793,
#   794,
#   803,
#   829,
#   830,
#   831,
#   844,
#   851,
#   852,
#   856,
#   859,
#   860,
#   871,
#   872,
#   880,
#   881,
#   882,
#   883,
#   884,
#   893,
#   895,
#   896,
#   904,
#   906,
#   907,
#   908,
#   922,
#   923,
#   933,
#   934,
#   948,
#   949,
#   950,
#   960,
#   961,
#   962,
#   969,
#   970,
#   971,
#   975,
#   976,
#   983,
#   985,
#   996,
#   997,
#   1008,
#   1010,
#   1017,
#   1018,
#   1024,
#   1028,
#   1036,
#   1037,
#   1051,
#   1052,
#   1053,
#   1063,
#   1074,
#   1081,
#   1082,
#   1083,
#   1084,
#   1091,
#   1096,
#   1102,
#   1108,
#   1109,
#   1117,
#   1118,
#   1119,
#   1120,
#   1124,
#   1125,
#   1126,
#   1128,
#   1129,
#   1130,
#   1131,
#   1144,
#   1154,
#   1155,
#   1170,
#   1181,
#   1185,
#   1186,
#   1194,
#   1195,
#   1204,
#   1205,
#   1215,
#   1221,
#   1222,
#   1231,
#   1243,
#   1244,
#   1245,
#   1249,
#   1250,
#   1251,
#   1255,
#   1256,
#   1268,
#   1277,
#   1278,
#   1279,
#   1280,
#   1289,
#   1290,
#   1291,
#   1292,
#   1301,
#   1302,
#   1303,
#   1304,
#   1305,
#   1306,
#   1307,
#   1327,
#   1328,
#   1331,
#   1332,
#   1343,
#   1344,
#   1345,
#   1356,
#   1357,
#   1358,
#   1363,
#   1370,
#   1371,
#   1376,
#   1377,
#   1378,
#   1379,
#   1387,
#   1388,
#   1390,
#   1391,
#   1409,
#   1410,
#   1411,
#   1412,
#   1413,
#   1423,
#   1425,
#   1435,
#   1439,
#   1441,
#   1458,
#   1459,
#   1466,
#   1469,
#   1478,
#   1487,
#   1488,
#   1489,
#   1490,
#   1491,
#   1502,
#   1503,
#   1504,
#   1516,
#   1517,
#   1518,
#   1519,
#   1526,
#   1538,
#   1549,
#   1550,
#   1559,
#   1560,
#   1561,
#   1562,
#   1569,
#   1570,
#   1571,
#   1572,
#   1573,
#   1574,
#   1575,
#   1580,
#   1581,
#   1589,
#   1590,
#   1591,
#   1592,
#   1600,
#   1601,
#   1619,
#   1628,
#   1629,
#   1633,
#   1634,
#   1641,
#   1642,
#   1643,
#   1651,
#   1652,
#   1664,
#   1678,
#   1679,
#   1695,
#   1696,
#   1697,
#   1700,
#   1701,
#   1702,
#   1703,
#   1704,
#   1725,
#   1726,
#   1731,
#   1740,
#   1746,
#   1753,
#   1755,
#   1756,
#   1766,
#   1773,
#   1774,
#   1782,
#   1783,
#   1794,
#   1796,
#   1797,
#   1798,
#   1806,
#   1807,
#   1808,
#   1812,
#   1822,
#   1823,
#   1824,
#   1825,
#   1837,
#   1845,
#   1853,
#   1854,
#   1855,
#   1865,
#   1867,
#   1868,
#   1874,
#   1875,
#   1876,
#   1888,
#   1889,
#   1890,
#   1891,
#   1899,
#   1900,
#   1901,
#   1910,
#   1913,
#   1918,
#   1919,
#   1924,
#   1925,
#   1933,
#   1934,
#   1935,
#   1936,
#   1937,
#   1942,
#   1943,
#   1944,
#   1945,
#   1946,
#   1947,
#   1948,
#   1963,
#   1964,
#   1965,
#   1967,
#   1968,
#   1969,
#   1979,
#   1980,
#   1986,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2011,
#   2012,
#   2013,
#   2014,
#   2024,
#   2031,
#   2032,
#   2037,
#   2038,
#   2039,
#   2046,
#   2057,
#   2058,
#   2059,
#   2067,
#   2068,
#   2094,
#   2095,
#   2096,
#   2097,
#   2098,
#   2102,
#   2103,
#   2104,
#   2115,
#   2116,
#   2131,
#   2132,
#   2136,
#   2147,
#   2148,
#   2161,
#   2165,
#   2171,
#   2172,
#   2180,
#   2192,
#   2193,
#   2196,
#   2197,
#   2198,
#   2205,
#   2216,
#   2217,
#   2226,
#   2236,
#   2237,
#   2251,
#   2252,
#   2262,
#   2263,
#   2274,
#   2282,
#   2283,
#   2284,
#   2285,
#   2292,
#   2301,
#   2305,
#   2306,
#   2308,
#   2326,
#   2327,
#   2328,
#   2344,
#   2345,
#   2353,
#   2357,
#   2366,
#   2367,
#   2375,
#   2376,
#   2377,
#   2384,
#   2385,
#   2398,
#   2406,
#   2407,
#   2408,
#   2409,
#   2422,
#   2423,
#   2424,
#   2435,
#   2436,
#   2437,
#   2447,
#   2448,
#   2453,
#   2454,
#   2460,
#   2464,
#   2469,
#   2470,
#   2471,
#   2481,
#   2482,
#   2493,
#   2502,
#   2503,
#   2504,
#   2522,
#   2523,
#   2524,
#   2529,
#   2530,
#   2531,
#   2532,
#   2533,
#   2539,
#   2542,
#   2543,
#   2547,
#   2548,
#   2549,
#   2559,
#   2560,
#   2567,
#   2568,
#   2573,
#   2576,
#   2580,
#   2581,
#   2587,
#   2588,
#   2589,
#   2601,
#   2602,
#   2609,
#   2610,
#   2611,
#   2619,
#   2620,
#   2630,
#   2638,
#   2639,
#   2645,
#   2646,
#   2653,
#   2654,
#   2659,
#   2665,
#   2674,
#   2675,
#   2677,
#   2678,
#   2684,
#   2685,
#   2686,
#   2696,
#   2705,
#   2706,
#   2713,
#   2723,
#   2731,
#   2732,
#   2733,
#   2734,
#   2735,
#   2740,
#   2748,
#   2749,
#   2750,
#   2755,
#   2773,
#   2784,
#   2785,
#   2786,
#   2797,
#   2798,
#   2799,
#   2806,
#   2807,
#   2813,
#   2814,
#   2815,
#   2816,
#   2817,
#   2825,
#   2826,
#   2828,
#   2829,
#   2840,
#   2841,
#   2852,
#   2853,
#   2868,
#   2875,
#   2876,
#   2877,
#   2887,
#   2888,
#   2889,
#   2890,
#   2903,
#   2904,
#   2909,
#   2910,
#   2911,
#   2912,
#   2913,
#   2919,
#   2923,
#   2924,
#   2931,
#   2932,
#   2941,
#   2949,
#   2950,
#   2957,
#   2962,
#   2963,
#   2964,
#   2969,
#   2970,
#   2976,
#   2978,
#   2988,
#   2993,
#   2994,
#   2995,
#   2996,
#   3004,
#   3005,
#   3017,
#   3018,
#   3019,
#   3025,
#   3026,
#   3036,
#   3037,
#   3046,
#   3047,
#   3048,
#   3053,
#   3054,
#   3055,
#   3071,
#   3078,
#   3079,
#   3080,
#   3081,
#   3102,
#   3103,
#   3104,
#   3105,
#   3112,
#   3120,
#   3130,
#   3131,
#   3138,
#   3146,
#   3149,
#   3150,
#   3151,
#   3152,
#   3159,
#   3164,
#   3173,
#   3178,
#   3179,
#   3180,
#   3188,
#   3189,
#   3190,
#   3191,
#   3197,
#   3198,
#   3203,
#   3211,
#   3219,
#   3220,
#   3226,
#   3236,
#   3237,
#   3244,
#   3245,
#   3246,
#   3250,
#   3256,
#   3261,
#   3262,
#   3271,
#   3272,
#   3282,
#   3283,
#   3289,
#   3298,
#   3299,
#   3315,
#   3325,
#   3326,
#   3331,
#   3332,
#   3338,
#   3343,
#   3344,
#   3345,
#   3346,
#   3347,
#   3348,
#   3353,
#   3354,
#   3355,
#   3365,
#   3366,
#   3367,
#   3379,
#   3384,
#   3385,
#   3391,
#   3392,
#   3395,
#   3396,
#   3404,
#   3405,
#   3409,
#   3410,
#   3418,
#   3424,
#   3425,
#   3430,
#   3445,
#   3454,
#   3460,
#   3462,
#   3468,
#   3477,
#   3478,
#   3479,
#   3490,
#   3497,
#   3498,
#   3499,
#   3500,
#   3504,
#   3505,
#   3515,
#   3516,
#   3517,
#   3524,
#   3532,
#   3541,
#   3542,
#   3543,
#   3544,
#   3548,
#   3549,
#   3556,
#   3557,
#   3558,
#   3559,
#   3569,
#   3570,
#   3571,
#   3572,
#   3573,
#   3588,
#   3597,
#   3598,
#   3617,
#   3618,
#   3627,
#   3635,
#   3636,
#   3637,
#   3638,
#   3646,
#   3653,
#   3661,
#   3662,
#   3663,
#   3669,
#   3670,
#   3679,
#   3684,
#   3685,
#   3694,
#   3712,
#   3719,
#   3720,
#   3721,
#   3729,
#   3737,
#   3738,
#   3739,
#   3744,
#   3745,
#   3746,
#   3757,
#   3780,
#   3786,
#   3789,
#   3790,
#   3791,
#   3799,
#   3800,
#   3808,
#   3809,
#   3810,
#   3820,
#   3824,
#   3825,
#   3826,
#   3832,
#   3833,
#   3834,
#   3856,
#   3868,
#   3869,
#   3870,
#   3879,
#   3887,
#   3888,
#   3895,
#   3907,
#   3908,
#   3909,
#   3917,
#   3919,
#   3924,
#   3925,
#   3926,
#   3927,
#   3937,
#   3938,
#   3939,
#   3949],
#  'Letter': [3,
#   4,
#   16,
#   40,
#   46,
#   75,
#   94,
#   104,
#   109,
#   119,
#   139,
#   159,
#   160,
#   165,
#   186,
#   187,
#   196,
#   208,
#   226,
#   227,
#   240,
#   241,
#   248,
#   249,
#   273,
#   274,
#   283,
#   298,
#   309,
#   323,
#   324,
#   386,
#   387,
#   398,
#   405,
#   413,
#   414,
#   415,
#   416,
#   438,
#   439,
#   446,
#   458,
#   479,
#   484,
#   485,
#   502,
#   515,
#   539,
#   546,
#   547,
#   552,
#   563,
#   589,
#   590,
#   599,
#   624,
#   625,
#   631,
#   669,
#   675,
#   683,
#   694,
#   705,
#   717,
#   723,
#   724,
#   761,
#   766,
#   779,
#   787,
#   795,
#   804,
#   818,
#   897,
#   898,
#   909,
#   910,
#   911,
#   935,
#   972,
#   977,
#   986,
#   1054,
#   1065,
#   1103,
#   1110,
#   1132,
#   1171,
#   1196,
#   1223,
#   1257,
#   1258,
#   1269,
#   1270,
#   1281,
#   1308,
#   1315,
#   1333,
#   1364,
#   1365,
#   1392,
#   1414,
#   1426,
#   1470,
#   1479,
#   1492,
#   1505,
#   1506,
#   1507,
#   1630,
#   1635,
#   1648,
#   1666,
#   1698,
#   1715,
#   1800,
#   1826,
#   1827,
#   1838,
#   1846,
#   1847,
#   1856,
#   1869,
#   1920,
#   1921,
#   1956,
#   1981,
#   2069,
#   2105,
#   2124,
#   2125,
#   2126,
#   2137,
#   2138,
#   2151,
#   2189,
#   2199,
#   2206,
#   2227,
#   2228,
#   2286,
#   2303,
#   2320,
#   2329,
#   2330,
#   2379,
#   2386,
#   2412,
#   2455,
#   2484,
#   2514,
#   2525,
#   2590,
#   2603,
#   2604,
#   2621,
#   2622,
#   2647,
#   2697,
#   2724,
#   2725,
#   2741,
#   2751,
#   2774,
#   2787,
#   2830,
#   2855,
#   2869,
#   2891,
#   2914,
#   2942,
#   2959,
#   2979,
#   2989,
#   3006,
#   3015,
#   3020,
#   3050,
#   3106,
#   3115,
#   3122,
#   3174,
#   3192,
#   3193,
#   3204,
#   3212,
#   3221,
#   3227,
#   3228,
#   3290,
#   3304,
#   3356,
#   3386,
#   3411,
#   3432,
#   3433,
#   3434,
#   3480,
#   3481,
#   3482,
#   3507,
#   3518,
#   3519,
#   3550,
#   3574,
#   3583,
#   3589,
#   3599,
#   3614,
#   3619,
#   3628,
#   3639,
#   3648,
#   3654,
#   3665,
#   3686,
#   3713,
#   3722,
#   3730,
#   3758,
#   3793,
#   3845,
#   3857,
#   3858,
#   3896,
#   3911,
#   3920,
#   3941],
#  'Book Review': [5,
#   27,
#   76,
#   77,
#   110,
#   120,
#   170,
#   179,
#   264,
#   335,
#   342,
#   388,
#   406,
#   417,
#   427,
#   447,
#   459,
#   471,
#   486,
#   553,
#   632,
#   650,
#   676,
#   706,
#   707,
#   734,
#   762,
#   806,
#   819,
#   845,
#   885,
#   899,
#   912,
#   924,
#   963,
#   1055,
#   1097,
#   1104,
#   1111,
#   1137,
#   1146,
#   1172,
#   1188,
#   1217,
#   1224,
#   1232,
#   1259,
#   1272,
#   1293,
#   1334,
#   1347,
#   1366,
#   1404,
#   1443,
#   1452,
#   1453,
#   1460,
#   1493,
#   1563,
#   1564,
#   1620,
#   1654,
#   1681,
#   1747,
#   1757,
#   1775,
#   1784,
#   1785,
#   1813,
#   1828,
#   1829,
#   1870,
#   1877,
#   1903,
#   1949,
#   1983,
#   1987,
#   2040,
#   2080,
#   2081,
#   2106,
#   2118,
#   2166,
#   2229,
#   2230,
#   2238,
#   2244,
#   2254,
#   2255,
#   2264,
#   2309,
#   2310,
#   2321,
#   2331,
#   2346,
#   2368,
#   2387,
#   2388,
#   2399,
#   2413,
#   2426,
#   2438,
#   2473,
#   2485,
#   2505,
#   2506,
#   2515,
#   2534,
#   2550,
#   2577,
#   2591,
#   2613,
#   2623,
#   2648,
#   2667,
#   2688,
#   2698,
#   2742,
#   2756,
#   2775,
#   2788,
#   2789,
#   2808,
#   2893,
#   2897,
#   2935,
#   2971,
#   2972,
#   2980,
#   3021,
#   3027,
#   3028,
#   3062,
#   3063,
#   3083,
#   3093,
#   3123,
#   3132,
#   3167,
#   3175,
#   3181,
#   3205,
#   3229,
#   3251,
#   3257,
#   3275,
#   3291,
#   3300,
#   3305,
#   3306,
#   3349,
#   3380,
#   3387,
#   3469,
#   3483,
#   3484,
#   3508,
#   3525,
#   3533,
#   3575,
#   3600,
#   3629,
#   3649,
#   3672,
#   3687,
#   3695,
#   3740,
#   3759,
#   3770,
#   3771,
#   3781,
#   3811,
#   3836,
#   3837,
#   3846,
#   3912,
#   3928,
#   3942,
#   3943],
#  'Article Commentary': [6,
#   7,
#   41,
#   42,
#   48,
#   54,
#   63,
#   78,
#   79,
#   88,
#   95,
#   96,
#   97,
#   121,
#   122,
#   140,
#   141,
#   149,
#   166,
#   171,
#   181,
#   189,
#   197,
#   198,
#   199,
#   210,
#   217,
#   218,
#   228,
#   229,
#   243,
#   244,
#   251,
#   252,
#   259,
#   260,
#   285,
#   292,
#   293,
#   300,
#   311,
#   325,
#   343,
#   344,
#   358,
#   359,
#   368,
#   375,
#   390,
#   407,
#   428,
#   448,
#   460,
#   461,
#   472,
#   480,
#   498,
#   504,
#   529,
#   530,
#   542,
#   548,
#   554,
#   556,
#   565,
#   566,
#   570,
#   577,
#   601,
#   610,
#   626,
#   633,
#   634,
#   642,
#   652,
#   685,
#   686,
#   718,
#   725,
#   743,
#   744,
#   764,
#   767,
#   768,
#   773,
#   780,
#   796,
#   797,
#   807,
#   808,
#   811,
#   820,
#   821,
#   822,
#   823,
#   834,
#   835,
#   836,
#   837,
#   847,
#   848,
#   849,
#   858,
#   863,
#   864,
#   867,
#   868,
#   869,
#   886,
#   900,
#   914,
#   915,
#   916,
#   917,
#   925,
#   926,
#   931,
#   936,
#   944,
#   945,
#   953,
#   954,
#   955,
#   959,
#   978,
#   989,
#   990,
#   995,
#   1000,
#   1001,
#   1002,
#   1003,
#   1011,
#   1025,
#   1030,
#   1031,
#   1038,
#   1056,
#   1057,
#   1066,
#   1076,
#   1077,
#   1086,
#   1087,
#   1090,
#   1098,
#   1099,
#   1100,
#   1105,
#   1134,
#   1138,
#   1139,
#   1147,
#   1148,
#   1149,
#   1150,
#   1163,
#   1173,
#   1174,
#   1175,
#   1189,
#   1190,
#   1206,
#   1207,
#   1208,
#   1225,
#   1226,
#   1227,
#   1230,
#   1235,
#   1236,
#   1237,
#   1238,
#   1241,
#   1261,
#   1263,
#   1264,
#   1276,
#   1282,
#   1294,
#   1295,
#   1296,
#   1309,
#   1313,
#   1317,
#   1318,
#   1319,
#   1335,
#   1336,
#   1337,
#   1342,
#   1359,
#   1360,
#   1367,
#   1374,
#   1381,
#   1395,
#   1406,
#   1407,
#   1416,
#   1417,
#   1418,
#   1427,
#   1444,
#   1472,
#   1481,
#   1482,
#   1485,
#   1495,
#   1496,
#   1508,
#   1509,
#   1523,
#   1527,
#   1528,
#   1529,
#   1530,
#   1534,
#   1535,
#   1541,
#   1542,
#   1551,
#   1552,
#   1553,
#   1566,
#   1576,
#   1582,
#   1583,
#   1584,
#   1593,
#   1604,
#   1612,
#   1623,
#   1656,
#   1660,
#   1667,
#   1668,
#   1669,
#   1682,
#   1686,
#   1690,
#   1705,
#   1706,
#   1707,
#   1708,
#   1717,
#   1727,
#   1733,
#   1742,
#   1748,
#   1749,
#   1759,
#   1767,
#   1776,
#   1777,
#   1787,
#   1801,
#   1814,
#   1815,
#   1830,
#   1839,
#   1848,
#   1858,
#   1859,
#   1879,
#   1880,
#   1881,
#   1892,
#   1893,
#   1915,
#   1938,
#   1950,
#   1957,
#   1958,
#   1959,
#   1971,
#   1972,
#   2005,
#   2006,
#   2007,
#   2015,
#   2025,
#   2026,
#   2048,
#   2049,
#   2050,
#   2061,
#   2062,
#   2070,
#   2079,
#   2082,
#   2107,
#   2108,
#   2117,
#   2127,
#   2133,
#   2134,
#   2140,
#   2141,
#   2153,
#   2162,
#   2173,
#   2181,
#   2183,
#   2184,
#   2186,
#   2188,
#   2194,
#   2195,
#   2200,
#   2201,
#   2204,
#   2208,
#   2209,
#   2210,
#   2218,
#   2231,
#   2232,
#   2233,
#   2240,
#   2245,
#   2256,
#   2257,
#   2258,
#   2265,
#   2266,
#   2271,
#   2287,
#   2288,
#   2293,
#   2294,
#   2295,
#   2302,
#   2319,
#   2323,
#   2325,
#   2332,
#   2333,
#   2338,
#   2339,
#   2347,
#   2358,
#   2359,
#   2365,
#   2369,
#   2378,
#   2380,
#   2381,
#   2400,
#   2410,
#   2414,
#   2415,
#   2425,
#   2427,
#   2433,
#   2440,
#   2441,
#   2456,
#   2463,
#   2465,
#   2468,
#   2472,
#   2474,
#   2475,
#   2476,
#   2483,
#   2486,
#   2487,
#   2496,
#   2517,
#   2521,
#   2526,
#   2553,
#   2562,
#   2565,
#   2578,
#   2582,
#   2592,
#   2606,
#   2614,
#   2624,
#   2629,
#   2633,
#   2640,
#   2641,
#   2643,
#   2655,
#   2666,
#   2668,
#   2679,
#   2689,
#   2699,
#   2700,
#   2707,
#   2714,
#   2715,
#   2716,
#   2726,
#   2727,
#   2736,
#   2743,
#   2752,
#   2753,
#   2759,
#   2761,
#   2791,
#   2800,
#   2805,
#   2818,
#   2819,
#   2832,
#   2838,
#   2842,
#   2843,
#   2844,
#   2845,
#   2846,
#   2854,
#   2857,
#   2860,
#   2861,
#   2862,
#   2878,
#   2879,
#   2933,
#   2936,
#   2958,
#   2960,
#   2973,
#   2974,
#   2975,
#   2981,
#   2982,
#   2997,
#   3011,
#   3022,
#   3038,
#   3039,
#   3049,
#   3052,
#   3056,
#   3064,
#   3065,
#   3066,
#   3072,
#   3082,
#   3085,
#   3086,
#   3087,
#   3094,
#   3095,
#   3099,
#   3107,
#   3108,
#   3114,
#   3117,
#   3121,
#   3133,
#   3134,
#   3139,
#   3140,
#   3153,
#   3154,
#   3160,
#   3168,
#   3183,
#   3184,
#   3199,
#   3201,
#   3206,
#   3209,
#   3214,
#   3222,
#   3241,
#   3247,
#   3253,
#   3263,
#   3264,
#   3265,
#   3266,
#   3273,
#   3284,
#   3292,
#   3293,
#   3303,
#   3316,
#   3317,
#   3327,
#   3339,
#   3340,
#   3350,
#   3357,
#   3358,
#   3368,
#   3369,
#   3370,
#   3377,
#   3388,
#   3397,
#   3398,
#   3399,
#   3413,
#   3414,
#   3419,
#   3426,
#   3427,
#   3431,
#   3435,
#   3441,
#   3443,
#   3446,
#   3448,
#   3463,
#   3464,
#   3486,
#   3487,
#   3491,
#   3492,
#   3506,
#   3509,
#   3510,
#   3526,
#   3534,
#   3545,
#   3551,
#   3552,
#   3560,
#   3561,
#   3567,
#   3576,
#   3582,
#   3590,
#   3591,
#   3601,
#   3607,
#   3621,
#   3647,
#   3650,
#   3655,
#   3664,
#   3666,
#   3667,
#   3671,
#   3673,
#   3674,
#   3675,
#   3680,
#   3688,
#   3689,
#   3696,
#   3697,
#   3698,
#   3702,
#   3703,
#   3704,
#   3705,
#   3715,
#   3716,
#   3723,
#   3724,
#   3731,
#   3732,
#   3733,
#   3734,
#   3747,
#   3748,
#   3761,
#   3762,
#   3768,
#   3782,
#   3787,
#   3792,
#   3801,
#   3802,
#   3803,
#   3812,
#   3821,
#   3822,
#   3828,
#   3835,
#   3838,
#   3839,
#   3840,
#   3847,
#   3848,
#   3860,
#   3861,
#   3871,
#   3872,
#   3873,
#   3880,
#   3889,
#   3897,
#   3898,
#   3900,
#   3902,
#   3910,
#   3929,
#   3940,
#   3944,
#   3945,
#   3950],
#  'Research Article': [8,
#   9,
#   10,
#   11,
#   19,
#   20,
#   21,
#   28,
#   34,
#   35,
#   36,
#   37,
#   43,
#   44,
#   50,
#   51,
#   52,
#   53,
#   64,
#   65,
#   66,
#   67,
#   68,
#   69,
#   89,
#   90,
#   91,
#   98,
#   99,
#   105,
#   106,
#   112,
#   113,
#   124,
#   125,
#   133,
#   134,
#   142,
#   143,
#   151,
#   161,
#   167,
#   168,
#   173,
#   174,
#   182,
#   183,
#   191,
#   192,
#   202,
#   203,
#   204,
#   205,
#   211,
#   212,
#   219,
#   220,
#   231,
#   232,
#   233,
#   234,
#   245,
#   246,
#   253,
#   266,
#   267,
#   268,
#   269,
#   277,
#   278,
#   279,
#   287,
#   288,
#   289,
#   294,
#   295,
#   302,
#   303,
#   304,
#   312,
#   313,
#   314,
#   315,
#   316,
#   317,
#   326,
#   327,
#   328,
#   329,
#   337,
#   346,
#   347,
#   351,
#   352,
#   353,
#   360,
#   361,
#   362,
#   363,
#   364,
#   369,
#   376,
#   377,
#   378,
#   379,
#   392,
#   400,
#   401,
#   402,
#   403,
#   404,
#   409,
#   410,
#   419,
#   430,
#   431,
#   440,
#   441,
#   442,
#   450,
#   451,
#   452,
#   462,
#   463,
#   473,
#   474,
#   475,
#   476,
#   477,
#   481,
#   482,
#   487,
#   491,
#   492,
#   499,
#   500,
#   506,
#   507,
#   508,
#   518,
#   519,
#   532,
#   533,
#   534,
#   535,
#   543,
#   544,
#   549,
#   550,
#   555,
#   567,
#   568,
#   569,
#   578,
#   579,
#   580,
#   581,
#   582,
#   591,
#   592,
#   602,
#   603,
#   611,
#   612,
#   613,
#   618,
#   619,
#   627,
#   628,
#   629,
#   635,
#   636,
#   637,
#   643,
#   644,
#   645,
#   653,
#   654,
#   655,
#   660,
#   661,
#   662,
#   663,
#   664,
#   671,
#   672,
#   677,
#   678,
#   679,
#   688,
#   689,
#   690,
#   691,
#   695,
#   696,
#   697,
#   698,
#   708,
#   709,
#   710,
#   711,
#   712,
#   713,
#   727,
#   736,
#   737,
#   747,
#   748,
#   749,
#   750,
#   755,
#   756,
#   757,
#   770,
#   771,
#   772,
#   781,
#   782,
#   783,
#   789,
#   790,
#   799,
#   800,
#   801,
#   802,
#   809,
#   810,
#   812,
#   813,
#   814,
#   815,
#   824,
#   825,
#   826,
#   838,
#   839,
#   840,
#   841,
#   842,
#   850,
#   857,
#   865,
#   866,
#   877,
#   878,
#   887,
#   888,
#   889,
#   890,
#   891,
#   901,
#   902,
#   919,
#   927,
#   928,
#   929,
#   930,
#   937,
#   938,
#   939,
#   940,
#   941,
#   942,
#   943,
#   956,
#   957,
#   958,
#   964,
#   965,
#   966,
#   967,
#   974,
#   979,
#   980,
#   981,
#   991,
#   992,
#   993,
#   994,
#   1005,
#   1006,
#   1007,
#   1012,
#   1013,
#   1014,
#   1015,
#   1026,
#   1032,
#   1033,
#   1034,
#   1040,
#   1041,
#   1042,
#   1043,
#   1044,
#   1045,
#   1046,
#   1058,
#   1059,
#   1060,
#   1068,
#   1069,
#   1070,
#   1071,
#   1078,
#   1079,
#   1088,
#   1089,
#   1093,
#   1094,
#   1095,
#   1106,
#   1113,
#   1122,
#   1123,
#   1136,
#   1140,
#   1141,
#   1151,
#   1152,
#   1153,
#   1158,
#   1159,
#   1160,
#   1164,
#   1165,
#   1166,
#   1167,
#   1168,
#   1176,
#   1177,
#   1178,
#   1179,
#   1180,
#   1191,
#   1192,
#   1198,
#   1199,
#   1200,
#   1209,
#   1210,
#   1211,
#   1219,
#   1220,
#   1229,
#   1240,
#   1246,
#   1247,
#   1248,
#   1252,
#   1253,
#   1262,
#   1265,
#   1273,
#   1274,
#   1283,
#   1284,
#   1285,
#   1286,
#   1287,
#   1297,
#   1298,
#   1299,
#   1300,
#   1311,
#   1312,
#   1320,
#   1321,
#   1322,
#   1323,
#   1324,
#   1329,
#   1339,
#   1340,
#   1341,
#   1350,
#   1351,
#   1368,
#   1372,
#   1373,
#   1383,
#   1384,
#   1385,
#   1386,
#   1397,
#   1398,
#   1399,
#   1400,
#   1408,
#   1420,
#   1428,
#   1429,
#   1430,
#   1431,
#   1432,
#   1433,
#   1434,
#   1446,
#   1447,
#   1448,
#   1454,
#   1455,
#   1456,
#   1461,
#   1462,
#   1463,
#   1464,
#   1465,
#   1473,
#   1474,
#   1475,
#   1476,
#   1477,
#   1483,
#   1484,
#   1497,
#   1498,
#   1499,
#   1512,
#   1520,
#   1521,
#   1522,
#   1531,
#   1532,
#   1533,
#   1543,
#   1544,
#   1545,
#   1554,
#   1555,
#   1556,
#   1557,
#   1567,
#   1577,
#   1578,
#   1579,
#   1586,
#   1587,
#   1588,
#   1594,
#   1595,
#   1596,
#   1597,
#   1605,
#   1606,
#   1607,
#   1608,
#   1609,
#   1613,
#   1614,
#   1615,
#   1616,
#   1617,
#   1621,
#   1622,
#   1631,
#   1632,
#   1636,
#   1637,
#   1638,
#   1639,
#   1640,
#   1657,
#   1658,
#   1661,
#   1662,
#   1663,
#   1670,
#   1671,
#   1672,
#   1673,
#   1674,
#   1683,
#   1684,
#   1685,
#   1689,
#   1692,
#   1709,
#   1710,
#   1711,
#   1712,
#   1718,
#   1720,
#   1721,
#   1722,
#   1728,
#   1729,
#   1730,
#   1734,
#   1735,
#   1736,
#   1737,
#   1743,
#   1744,
#   1750,
#   1751,
#   1752,
#   1760,
#   1761,
#   1762,
#   1763,
#   1764,
#   1768,
#   1769,
#   1770,
#   1778,
#   1779,
#   1780,
#   1788,
#   1789,
#   1790,
#   1803,
#   1804,
#   1805,
#   1809,
#   1810,
#   1811,
#   1817,
#   1818,
#   1819,
#   1820,
#   1821,
#   1831,
#   1832,
#   1833,
#   1834,
#   1835,
#   1840,
#   1841,
#   1842,
#   1843,
#   1844,
#   1849,
#   1850,
#   1851,
#   1861,
#   1862,
#   1863,
#   1871,
#   1872,
#   1882,
#   1883,
#   1884,
#   1885,
#   1886,
#   1894,
#   1895,
#   1896,
#   1897,
#   1905,
#   1906,
#   1907,
#   1908,
#   1916,
#   1917,
#   1922,
#   1926,
#   1927,
#   1928,
#   1929,
#   1930,
#   1939,
#   1940,
#   1951,
#   1952,
#   1953,
#   1960,
#   1961,
#   1962,
#   1966,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1988,
#   1989,
#   1990,
#   1994,
#   1995,
#   1996,
#   1997,
#   2008,
#   2009,
#   2010,
#   2018,
#   2019,
#   2020,
#   2021,
#   2022,
#   2027,
#   2028,
#   2029,
#   2035,
#   2036,
#   2041,
#   2042,
#   2043,
#   2044,
#   2051,
#   2052,
#   2053,
#   2054,
#   2064,
#   2065,
#   2071,
#   2072,
#   2073,
#   2074,
#   2075,
#   2076,
#   2077,
#   2083,
#   2084,
#   2085,
#   2086,
#   2090,
#   2091,
#   2092,
#   2093,
#   2099,
#   2109,
#   2110,
#   2111,
#   2112,
#   2119,
#   2120,
#   2121,
#   2122,
#   2129,
#   2130,
#   2142,
#   2143,
#   2144,
#   2145,
#   2146,
#   2154,
#   2155,
#   2156,
#   2157,
#   2158,
#   2159,
#   2164,
#   2168,
#   2175,
#   2176,
#   2177,
#   2185,
#   2190,
#   2191,
#   2202,
#   2203,
#   2212,
#   2213,
#   2214,
#   2215,
#   2219,
#   2220,
#   2221,
#   2222,
#   2223,
#   2234,
#   2242,
#   2243,
#   2246,
#   2247,
#   2248,
#   2249,
#   2259,
#   2260,
#   2261,
#   2267,
#   2268,
#   2269,
#   2270,
#   2276,
#   2277,
#   2278,
#   2279,
#   2289,
#   2296,
#   2297,
#   2298,
#   2299,
#   2304,
#   2311,
#   2312,
#   2313,
#   2314,
#   2315,
#   2324,
#   2334,
#   2335,
#   2336,
#   2337,
#   2340,
#   2341,
#   2343,
#   2349,
#   2350,
#   2351,
#   2360,
#   2361,
#   2362,
#   2363,
#   2364,
#   2370,
#   2372,
#   2373,
#   2374,
#   2382,
#   2383,
#   2390,
#   2391,
#   2392,
#   2393,
#   2401,
#   2402,
#   2403,
#   2404,
#   2416,
#   2417,
#   2418,
#   2419,
#   2428,
#   2430,
#   2431,
#   2432,
#   2443,
#   2444,
#   2449,
#   2450,
#   2451,
#   2452,
#   2457,
#   2458,
#   2461,
#   2462,
#   2466,
#   2467,
#   2477,
#   2478,
#   2488,
#   2489,
#   2490,
#   2491,
#   2498,
#   2499,
#   2509,
#   2510,
#   2511,
#   2519,
#   2520,
#   2527,
#   2528,
#   2537,
#   2538,
#   2544,
#   2545,
#   2554,
#   2555,
#   2556,
#   2557,
#   2563,
#   2564,
#   2569,
#   2570,
#   2571,
#   2572,
#   2575,
#   2583,
#   2584,
#   2585,
#   2586,
#   2593,
#   2594,
#   2595,
#   2596,
#   2597,
#   2607,
#   2608,
#   2615,
#   2616,
#   2617,
#   2626,
#   2627,
#   2628,
#   2634,
#   2635,
#   2636,
#   2637,
#   2642,
#   2650,
#   2651,
#   2656,
#   2657,
#   2658,
#   2660,
#   2663,
#   2669,
#   2670,
#   2672,
#   2673,
#   2680,
#   2681,
#   2682,
#   2683,
#   2690,
#   2691,
#   2692,
#   2693,
#   2694,
#   2695,
#   2703,
#   2704,
#   2710,
#   2711,
#   2712,
#   2717,
#   2718,
#   2719,
#   2720,
#   2721,
#   2729,
#   2730,
#   2737,
#   2738,
#   2739,
#   2745,
#   2754,
#   2758,
#   2762,
#   2763,
#   2764,
#   2765,
#   2766,
#   2767,
#   2768,
#   2769,
#   2776,
#   2778,
#   2779,
#   2780,
#   2781,
#   2782,
#   2790,
#   2792,
#   2794,
#   2795,
#   2801,
#   2802,
#   2803,
#   2804,
#   2809,
#   2810,
#   2811,
#   2820,
#   2821,
#   2822,
#   2823,
#   2824,
#   2831,
#   2833,
#   2834,
#   2835,
#   2836,
#   2837,
#   2847,
#   2848,
#   2849,
#   2856,
#   2863,
#   2870,
#   2871,
#   2872,
#   2873,
#   2874,
#   2880,
#   2881,
#   2882,
#   2883,
#   2884,
#   2885,
#   2894,
#   2895,
#   2896,
#   2898,
#   2899,
#   2900,
#   2901,
#   2905,
#   2906,
#   2907,
#   2908,
#   2915,
#   2916,
#   2917,
#   2918,
#   2925,
#   2926,
#   2927,
#   2928,
#   2929,
#   2937,
#   2938,
#   2939,
#   2944,
#   2945,
#   2946,
#   2947,
#   2948,
#   2952,
#   2953,
#   2954,
#   2955,
#   2961,
#   2966,
#   2967,
#   2983,
#   2984,
#   2985,
#   2986,
#   2991,
#   2992,
#   2999,
#   3000,
#   3001,
#   3003,
#   3007,
#   3008,
#   3009,
#   3010,
#   3012,
#   3013,
#   3016,
#   3023,
#   3024,
#   3030,
#   3031,
#   3032,
#   3033,
#   3040,
#   3041,
#   3043,
#   3044,
#   3045,
#   3057,
#   3058,
#   3059,
#   3060,
#   3067,
#   3068,
#   3073,
#   3074,
#   3075,
#   3076,
#   3088,
#   3089,
#   3090,
#   3091,
#   3096,
#   3097,
#   3098,
#   3109,
#   3110,
#   3111,
#   3118,
#   3119,
#   3124,
#   3125,
#   3126,
#   3127,
#   3128,
#   3135,
#   3136,
#   3143,
#   3144,
#   3145,
#   3148,
#   3155,
#   3156,
#   3157,
#   3161,
#   3162,
#   3163,
#   3169,
#   3170,
#   3176,
#   3177,
#   3185,
#   3195,
#   3196,
#   3207,
#   3208,
#   3216,
#   3217,
#   3223,
#   3224,
#   3225,
#   3230,
#   ...],
#  'None': [12,
#   29,
#   30,
#   56,
#   73,
#   86,
#   92,
#   108,
#   128,
#   135,
#   136,
#   144,
#   153,
#   162,
#   185,
#   193,
#   194,
#   206,
#   207,
#   238,
#   247,
#   258,
#   270,
#   272,
#   280,
#   297,
#   318,
#   319,
#   331,
#   333,
#   365,
#   372,
#   382,
#   423,
#   432,
#   443,
#   455,
#   511,
#   522,
#   551,
#   558,
#   572,
#   574,
#   605,
#   638,
#   647,
#   656,
#   673,
#   680,
#   682,
#   692,
#   700,
#   715,
#   719,
#   731,
#   739,
#   751,
#   765,
#   816,
#   828,
#   843,
#   854,
#   870,
#   873,
#   894,
#   905,
#   920,
#   947,
#   984,
#   1009,
#   1023,
#   1050,
#   1061,
#   1064,
#   1073,
#   1107,
#   1142,
#   1161,
#   1202,
#   1203,
#   1214,
#   1267,
#   1275,
#   1288,
#   1314,
#   1326,
#   1330,
#   1354,
#   1361,
#   1375,
#   1389,
#   1421,
#   1424,
#   1437,
#   1438,
#   1440,
#   1450,
#   1501,
#   1514,
#   1524,
#   1536,
#   1537,
#   1548,
#   1568,
#   1598,
#   1618,
#   1625,
#   1649,
#   1650,
#   1659,
#   1665,
#   1676,
#   1694,
#   1713,
#   1714,
#   1723,
#   1739,
#   1745,
#   1754,
#   1771,
#   1792,
#   1795,
#   1864,
#   1866,
#   1873,
#   1911,
#   1931,
#   1941,
#   1954,
#   1985,
#   2030,
#   2045,
#   2055,
#   2088,
#   2150,
#   2169,
#   2179,
#   2225,
#   2250,
#   2280,
#   2290,
#   2300,
#   2316,
#   2317,
#   2355,
#   2356,
#   2397,
#   2420,
#   2434,
#   2446,
#   2500,
#   2664,
#   2746,
#   2771,
#   2772,
#   2783,
#   2864,
#   2866,
#   2886,
#   2902,
#   2940,
#   3034,
#   3077,
#   3101,
#   3172,
#   3186,
#   3202,
#   3218,
#   3242,
#   3288,
#   3295,
#   3297,
#   3336,
#   3393,
#   3403,
#   3408,
#   3417,
#   3440,
#   3474,
#   3530,
#   3540,
#   3547,
#   3554,
#   3596,
#   3606,
#   3612,
#   3626,
#   3660,
#   3743,
#   3754,
#   3755,
#   3817,
#   3867,
#   3894,
#   3918,
#   3948],
#  'Brief Report': [18,
#   172,
#   230,
#   265,
#   276,
#   301,
#   418,
#   531,
#   687,
#   726,
#   746,
#   754,
#   788,
#   798,
#   918,
#   1004,
#   1039,
#   1067,
#   1218],
#  'Review Article': [22,
#   49,
#   55,
#   111,
#   115,
#   116,
#   117,
#   150,
#   152,
#   190,
#   201,
#   223,
#   256,
#   336,
#   381,
#   394,
#   429,
#   505,
#   509,
#   510,
#   594,
#   745,
#   759,
#   769,
#   776,
#   968,
#   1019,
#   1020,
#   1021,
#   1022,
#   1047,
#   1048,
#   1115,
#   1127,
#   1157,
#   1182,
#   1183,
#   1184,
#   1201,
#   1212,
#   1228,
#   1254,
#   1310,
#   1325,
#   1338,
#   1382,
#   1396,
#   1402,
#   1419,
#   1436,
#   1467,
#   1510,
#   1511,
#   1546,
#   1624,
#   1644,
#   1645,
#   1738,
#   1816,
#   1993,
#   2017,
#   2023,
#   2034,
#   2063,
#   2100,
#   2113,
#   2114,
#   2128,
#   2149,
#   2163,
#   2174,
#   2178,
#   2211,
#   2224,
#   2241,
#   2275,
#   2307,
#   2348,
#   2354,
#   2371,
#   2395,
#   2396,
#   2429,
#   2445,
#   2497,
#   2508,
#   2536,
#   2574,
#   2618,
#   2671,
#   2676,
#   2744,
#   2777,
#   2793,
#   2920,
#   2921,
#   2922,
#   2951,
#   2965,
#   2977,
#   2998,
#   3014,
#   3042,
#   3069,
#   3113,
#   3137,
#   3194,
#   3210,
#   3320,
#   3329,
#   3352,
#   3389,
#   3402,
#   3444,
#   3451,
#   3496,
#   3523,
#   3537,
#   3615,
#   3630,
#   3752,
#   3753,
#   3774,
#   3841,
#   3882,
#   3893,
#   3922],
#  'Editorial': [23,
#   100,
#   154,
#   257,
#   305,
#   330,
#   464,
#   478,
#   483,
#   604,
#   614,
#   639,
#   646,
#   681,
#   693,
#   714,
#   853,
#   903,
#   1027,
#   1049,
#   1101,
#   1143,
#   1169,
#   1449,
#   1468,
#   1513,
#   1558,
#   1599,
#   1610,
#   1626,
#   1646,
#   1677,
#   1693,
#   1765,
#   1772,
#   1791,
#   1836,
#   1852,
#   1898,
#   1912,
#   1923,
#   1984,
#   2087,
#   2101,
#   2123,
#   2160,
#   2291,
#   2405,
#   2421,
#   2459,
#   2479,
#   2501,
#   2540,
#   2546,
#   2558,
#   2566,
#   2599,
#   2652,
#   2722,
#   2747,
#   2812,
#   2827,
#   2839,
#   2865,
#   2930,
#   2968,
#   3061,
#   3070,
#   3092,
#   3165,
#   3296,
#   3423,
#   3475,
#   3514,
#   3568,
#   3587,
#   3613,
#   3683,
#   3784,
#   3806,
#   3818,
#   3831,
#   3923],
#  'Correction': [26,
#   47,
#   132,
#   209,
#   214,
#   242,
#   263,
#   334,
#   399,
#   470,
#   497,
#   670,
#   684,
#   753,
#   805,
#   832,
#   875,
#   951,
#   973,
#   987,
#   998,
#   1075,
#   1187,
#   1197,
#   1216,
#   1271,
#   1380,
#   1403,
#   1442,
#   1540,
#   1602,
#   1653,
#   1680,
#   1741,
#   1857,
#   2004],
#  'Reply': [62,
#   188,
#   275,
#   290,
#   397,
#   426,
#   496,
#   545,
#   557,
#   665,
#   716,
#   827,
#   861,
#   862,
#   874,
#   892,
#   932,
#   946,
#   1085,
#   1145,
#   1193,
#   1242,
#   1346,
#   1369,
#   1401,
#   1539,
#   1687,
#   1799,
#   1902,
#   1982,
#   1991,
#   2033,
#   2047,
#   2089,
#   2253,
#   2272,
#   2411,
#   2512,
#   2513,
#   2598,
#   2612,
#   2661,
#   2687,
#   2770,
#   2850,
#   2858,
#   2892,
#   2934,
#   2943,
#   2987,
#   3002,
#   3100,
#   3166,
#   3171,
#   3213,
#   3274,
#   3281,
#   3324,
#   3769,
#   3779,
#   3798,
#   3866,
#   3878],
#  'Introduction': [380,
#   393,
#   699,
#   1016,
#   1072,
#   1080,
#   1114,
#   1352,
#   1547,
#   1675,
#   1691,
#   1699,
#   1781,
#   1909,
#   2066,
#   2352,
#   2394,
#   2662,
#   3401,
#   3459,
#   3539],
#  'Obituary': [391, 449, 1121, 1135, 1802, 3215, 3449],
#  'Retraction': [408, 1719, 2342]}

# %%
lists = []
s = 'year'
json_index[s] = {}
n = 0
for paper in papers:
    year = paper['date'][:4]
    if year in json_index[s]:
        json_index[s][year].append(paper['id'])
    else:
        json_index[s][year] = [paper['id']]

# %%
json_index['year']['2015']
# Out:
# [2273,
#  2274,
#  2275,
#  2276,
#  2277,
#  2278,
#  2279,
#  2280,
#  2281,
#  2282,
#  2283,
#  2284,
#  2285,
#  2286,
#  2287,
#  2288,
#  2289,
#  2290,
#  2291,
#  2292,
#  2293,
#  2294,
#  2295,
#  2296,
#  2297,
#  2298,
#  2299,
#  2300,
#  2301,
#  2302,
#  2303,
#  2304,
#  2305,
#  2306,
#  2307,
#  2308,
#  2309,
#  2310,
#  2311,
#  2312,
#  2313,
#  2314,
#  2315,
#  2316,
#  2317,
#  2318,
#  2319,
#  2320,
#  2321,
#  2322,
#  2323,
#  2324,
#  2325,
#  2326,
#  2327,
#  2328,
#  2329,
#  2330,
#  2331,
#  2332,
#  2333,
#  2334,
#  2335,
#  2336,
#  2337,
#  2338,
#  2339,
#  2340,
#  2341,
#  2342,
#  2343,
#  2344,
#  2345,
#  2346,
#  2347,
#  2348,
#  2349,
#  2350,
#  2351,
#  2352,
#  2353,
#  2354,
#  2355,
#  2356,
#  2357,
#  2358,
#  2359,
#  2360,
#  2361,
#  2362,
#  2363,
#  2364,
#  2365,
#  2366,
#  2367,
#  2368,
#  2369,
#  2370,
#  2371,
#  2372,
#  2373,
#  2374,
#  2375,
#  2376,
#  2377,
#  2378,
#  2379,
#  2380,
#  2381,
#  2382,
#  2383,
#  2384,
#  2385,
#  2386,
#  2387,
#  2388,
#  2389,
#  2390,
#  2391,
#  2392,
#  2393,
#  2394,
#  2395,
#  2396,
#  2397,
#  2398,
#  2399,
#  2400,
#  2401,
#  2402,
#  2403,
#  2404,
#  2405,
#  2406,
#  2407,
#  2408,
#  2409,
#  2410,
#  2411,
#  2412,
#  2413,
#  2414,
#  2415,
#  2416,
#  2417,
#  2418,
#  2419,
#  2420,
#  2421,
#  2422,
#  2423,
#  2424,
#  2425,
#  2426,
#  2427,
#  2428,
#  2429,
#  2430,
#  2431,
#  2432,
#  2433,
#  2434,
#  2435,
#  2436,
#  2437,
#  2438,
#  2439,
#  2440,
#  2441,
#  2442,
#  2443,
#  2444,
#  2445,
#  2446,
#  2447,
#  2448,
#  2449,
#  2450,
#  2451,
#  2452,
#  2453,
#  2454,
#  2455,
#  2456,
#  2457,
#  2458,
#  2459,
#  2460,
#  2461,
#  2462,
#  2463,
#  2464,
#  2465,
#  2466,
#  2467,
#  2468,
#  2469,
#  2470,
#  2471,
#  2472,
#  2473,
#  2474,
#  2475,
#  2476,
#  2477,
#  2478,
#  2479,
#  2480,
#  2481,
#  2482,
#  2483,
#  2484,
#  2485,
#  2486,
#  2487,
#  2488,
#  2489,
#  2490,
#  2491,
#  2492,
#  2493,
#  2494,
#  2495,
#  2496,
#  2497,
#  2498,
#  2499,
#  2500,
#  2501,
#  2502,
#  2503,
#  2504,
#  2505,
#  2506,
#  2507,
#  2508,
#  2509,
#  2510,
#  2511,
#  2512,
#  2513,
#  2514,
#  2515,
#  2516,
#  2517,
#  2518,
#  2519,
#  2520,
#  2521,
#  2522,
#  2523,
#  2524,
#  2525,
#  2526,
#  2527,
#  2528,
#  2529,
#  2530,
#  2531,
#  2532,
#  2533,
#  2534,
#  2535,
#  2536,
#  2537,
#  2538,
#  2539,
#  2540,
#  2541,
#  2542,
#  2543,
#  2544,
#  2545,
#  2546,
#  2547,
#  2548,
#  2549,
#  2550,
#  2551,
#  2552,
#  2553,
#  2554,
#  2555,
#  2556,
#  2557,
#  2558,
#  2559,
#  2560,
#  2561,
#  2562,
#  2563,
#  2564,
#  2565,
#  2566,
#  2567,
#  2568,
#  2569,
#  2570,
#  2571,
#  2572,
#  2573,
#  2574,
#  2575,
#  2576,
#  2577,
#  2578,
#  2579,
#  2580,
#  2581,
#  2582,
#  2583,
#  2584,
#  2585,
#  2586,
#  2587,
#  2588,
#  2589,
#  2590,
#  2591,
#  2592,
#  2593,
#  2594,
#  2595,
#  2596,
#  2597,
#  2598,
#  2599,
#  2600,
#  2601,
#  2602,
#  2603,
#  2604,
#  2605,
#  2606,
#  2607,
#  2608,
#  2609,
#  2610,
#  2611,
#  2612,
#  2613,
#  2614,
#  2615,
#  2616,
#  2617,
#  2618,
#  2619,
#  2620,
#  2621,
#  2622,
#  2623,
#  2624,
#  2625,
#  2626,
#  2627,
#  2628,
#  2629,
#  2630,
#  2631,
#  2632,
#  2633,
#  2634,
#  2635,
#  2636,
#  2637,
#  2638,
#  2639,
#  2640,
#  2641,
#  2642,
#  2643,
#  2644,
#  2645,
#  2646,
#  2647,
#  2648,
#  2649,
#  2650,
#  2651,
#  2652,
#  2653,
#  2654,
#  2655,
#  2656,
#  2657,
#  2658,
#  2659,
#  2660,
#  2661,
#  2662,
#  2663,
#  2664,
#  2665,
#  2666,
#  2667,
#  2668,
#  2669,
#  2670,
#  2671,
#  2672,
#  2673,
#  2674,
#  2675,
#  2676,
#  2677,
#  2678,
#  2679,
#  2680,
#  2681,
#  2682,
#  2683,
#  2684,
#  2685,
#  2686,
#  2687,
#  2688,
#  2689,
#  2690,
#  2691,
#  2692,
#  2693,
#  2694,
#  2695,
#  2696,
#  2697,
#  2698,
#  2699,
#  2700,
#  2701,
#  2702,
#  2703,
#  2704,
#  2705,
#  2706,
#  2707,
#  2708,
#  2709,
#  2710,
#  2711,
#  2712,
#  2713,
#  2714,
#  2715,
#  2716,
#  2717,
#  2718,
#  2719,
#  2720,
#  2721,
#  2722,
#  2723,
#  2724,
#  2725,
#  2726,
#  2727,
#  2728,
#  2729,
#  2730]

# %%
lists = []
s = 'author'
json_index[s] = {}
n = 0
for paper in papers:
    for author in paper[s]:
        author = re.sub('[^a-z ]','', author.lower())
        if author in json_index[s]:
            json_index['author'][author].append(paper['id'])
        else:
            json_index['author'][author] = [paper['id']]

# %%
json_index['author'].keys()
# Out:
# dict_keys(['elizabeth finkel', 'patrick a jansen', 'helene c mullerlandau', 's joseph wright', 'jeremy t bruskotter', 'eric toman', 'sherry a enzler', 'robert h schmidt', 'rosemary g gillespie', 'kenneth r lang', 'david j colehamilton', 'hua hu', 'marco martina', 'peter jonas', 'dovi poznanski', 'ryan chornock', 'peter e nugent', 'joshua s bloom', 'alexei v filippenko', 'mohan ganeshalingam', 'douglas c leonard', 'weidong li', 'rollin c thomas', 'john simon', 'vladimir protasenko', 'chuanxin lian', 'huili xing', 'debdeep jena', 'fuquan liu', 'sebastian marquardt', 'clare lister', 'szymon swiezewski', 'caroline dean', 'erik stokstad', 'michael bawaya', 'k brad wray', 'm a palmer', 'e s bernhardt', 'w h schlesinger', 'k n eshleman', 'e foufoulageorgiou', 'm s hendryx', 'a d lemly', 'g e likens', 'o l loucks', 'm e power', 'p s white', 'p r wilcock', 'nichola j raihani', 'alexandra s grutter', 'redouan bshary', 'shannon w boettcher', 'joshua m spurgeon', 'morgan c putnam', 'emily l warren', 'daniel b turnerevans', 'michael d kelzenberg', 'james r maiolo', 'harry a atwater', 'nathan s lewis', 'tetsuo irifune', 'toru shinmei', 'catherine a mccammon', 'nobuyoshi miyajima', 'david c rubie', 'daniel j frost', 'robert e lanford', 'elisabeth s hildebrandteriksen', 'andreas petri', 'robert persson', 'morten lindow', 'martin e munk', 'sakari kauppinen', 'henrik rum', 'jan rehwinkel', 'caetano reis e sousa', 'paul g thomas', 'peter c doherty', 'robert f service', 'martin enserink', 'nicolaas a rupke', 'john h werren', 'stephen richards', 'christopher a desjardins', 'oliver niehuis', 'jrgen gadau', 'john k colbourne', 'the nasonia genome working group', 'richard stone', 'hao xin', 'michael balter', 'jill p mesirov', 'michael costanzo', 'anastasia baryshnikova', 'jeremy bellay', 'yungil kim', 'eric d spear', 'carolyn s sevier', 'huiming ding', 'judice ly koh', 'kiana toufighi', 'sara mostafavi', 'jeany prinz', 'robert p st onge', 'benjamin vandersluis', 'taras makhnevych', 'franco j vizeacoumar', 'solmaz alizadeh', 'sondra bahr', 'renee l brost', 'yiqun chen', 'murat cokol', 'raamesh deshpande', 'zhijian li', 'zhenyuan lin', 'wendy liang', 'michaela marback', 'jadine paw', 'bryanjoseph san luis', 'ermira shuteriqi', 'amy hin yan tong', 'nydia van dyk', 'iain m wallace', 'joseph a whitney', 'matthew t weirauch', 'guoqing zhong', 'hongwei zhu', 'walid a houry', 'michael brudno', 'sasan ragibizadeh', 'balzs papp', 'csaba pl', 'frederick p roth', 'guri giaever', 'corey nislow', 'olga g troyanskaya', 'howard bussey', 'gary d bader', 'anneclaude gingras', 'quaid d morris', 'philip m kim', 'chris a kaiser', 'chad l myers', 'brenda j andrews', 'charles boone', 'atsushi tero', 'seiji takagi', 'tetsu saigusa', 'kentaro ito', 'dan p bebber', 'mark d fricker', 'kenji yumiki', 'ryo kobayashi', 'toshiyuki nakagaki', 'rajesh ganapathy', 'mark r buckley', 'sharon j gerbode', 'itai cohen', 'eyal rotenberg', 'dan yakir', 'elizabeth pennisi', 'zen faulkes', 'cyrus r safinya', 'youli li', 'terry harrison', 'zenghui wang', 'jiang wei', 'peter morse', 'j gregory dash', 'oscar e vilches', 'david h cobden', 'mark s chen', 'm christina white', 'ann gibbons', 'gregory s paul', 'felicity alcock', 'abigail clements', 'chaille webb', 'trevor lithgow', 'frederic geissmann', 'markus g manz', 'steffen jung', 'michael h sieweke', 'miriam merad', 'klaus ley', 'david ehre', 'etay lavert', 'meir lahav', 'igor lubomirsky', 'dalin shi', 'yan xu', 'brian m hopkinson', 'franois m m morel', 'peng ge', 'jun tsao', 'stan schein', 'todd j green', 'ming luo', 'z hong zhou', 'robert j smith', 'justin t okano', 'james s kahn', 'erin n bodine', 'sally blower', 'magda claeys', 'gebisa ejeta', 'adrian cho', 'eli kintisch', 'timothy d searchinger', 'steven p hamburg', 'jerry melillo', 'william chameides', 'petr havlik', 'daniel m kammen', 'gene e likens', 'michael obersteiner', 'michael oppenheimer', 'g philip robertson', 'william h schlesinger', 'g david tilman', 'ruben lubowski', 'vivian g ...

# %%
lists = []
s = 'institution'
json_index[s] = {}
n = 0
for paper in papers:
    for author in paper['authorInstitution']:
        author = re.sub('[^a-z ]','', author.lower())
        if not word or len(word)<2: continue
        if word in stop_words: continue
        if author in json_index[s]:
            json_index[s][author].append(paper['id'])
        else:
            json_index[s][author] = [paper['id']]

# %%
json_index['authorWords'] = {}
for name in json_index['author'].keys():
    for word in re.sub('[^a-z]',' ',name.lower()).split():
        if not word or len(word)<2: continue
        if word.lower() in json_index['authorWords']:
            json_index['authorWords'][word.lower()].append(name)
        else:
            json_index['authorWords'][word.lower()] = [name]

# %%
json_index['authorWords'].keys()
# Out:
# dict_keys(['elizabeth', 'finkel', 'patrick', 'jansen', 'helene', 'muller', 'landau', 'joseph', 'wright', 'jeremy', 'bruskotter', 'eric', 'toman', 'sherry', 'enzler', 'robert', 'schmidt', 'rosemary', 'gillespie', 'kenneth', 'lang', 'david', 'cole', 'hamilton', 'hua', 'hu', 'marco', 'martina', 'peter', 'jonas', 'dovi', 'poznanski', 'ryan', 'chornock', 'nugent', 'joshua', 'bloom', 'alexei', 'filippenko', 'mohan', 'ganeshalingam', 'douglas', 'leonard', 'weidong', 'li', 'rollin', 'thomas', 'john', 'simon', 'vladimir', 'protasenko', 'chuanxin', 'lian', 'huili', 'xing', 'debdeep', 'jena', 'fuquan', 'liu', 'sebastian', 'marquardt', 'clare', 'lister', 'szymon', 'swiezewski', 'caroline', 'dean', 'erik', 'stokstad', 'michael', 'bawaya', 'brad', 'wray', 'palmer', 'bernhardt', 'schlesinger', 'eshleman', 'foufoula', 'georgiou', 'hendryx', 'lemly', 'likens', 'loucks', 'power', 'white', 'wilcock', 'nichola', 'raihani', 'alexandra', 'grutter', 'redouan', 'bshary', 'shannon', 'boettcher', 'spurgeon', 'morgan', 'putnam', 'emily', 'warren', 'daniel', 'turner', 'evans', 'kelzenberg', 'james', 'maiolo', 'harry', 'atwater', 'nathan', 'lewis', 'tetsuo', 'irifune', 'toru', 'shinmei', 'catherine', 'mccammon', 'nobuyoshi', 'miyajima', 'rubie', 'frost', 'lanford', 'elisabeth', 'hildebrandt', 'eriksen', 'andreas', 'petri', 'persson', 'morten', 'lindow', 'martin', 'munk', 'sakari', 'kauppinen', 'henrik', 'rum', 'jan', 'rehwinkel', 'caetano', 'reis', 'sousa', 'paul', 'doherty', 'service', 'enserink', 'nicolaas', 'rupke', 'werren', 'stephen', 'richards', 'christopher', 'desjardins', 'oliver', 'niehuis', 'rgen', 'gadau', 'colbourne', 'the', 'nasonia', 'genome', 'working', 'group', 'richard', 'stone', 'hao', 'xin', 'balter', 'jill', 'mesirov', 'costanzo', 'anastasia', 'baryshnikova', 'bellay', 'yungil', 'kim', 'spear', 'carolyn', 'sevier', 'huiming', 'ding', 'judice', 'koh', 'kiana', 'toufighi', 'sara', 'mostafavi', 'jeany', 'prinz', 'st', 'onge', 'benjamin', 'vandersluis', 'taras', 'makhnevych', 'franco', 'vizeacoumar', 'solmaz', 'alizadeh', 'sondra', 'bahr', 'renee', 'brost', 'yiqun', 'chen', 'murat', 'cokol', 'raamesh', 'deshpande', 'zhijian', 'zhen', 'yuan', 'lin', 'wendy', 'liang', 'michaela', 'marback', 'jadine', 'paw', 'bryan', 'san', 'luis', 'ermira', 'shuteriqi', 'amy', 'hin', 'yan', 'tong', 'nydia', 'van', 'dyk', 'iain', 'wallace', 'whitney', 'matthew', 'weirauch', 'guoqing', 'zhong', 'hongwei', 'zhu', 'walid', 'houry', 'brudno', 'sasan', 'ragibizadeh', 'bal', 'zs', 'papp', 'csaba', 'frederick', 'roth', 'guri', 'giaever', 'corey', 'nislow', 'olga', 'troyanskaya', 'howard', 'bussey', 'gary', 'bader', 'anne', 'claude', 'gingras', 'quaid', 'morris', 'philip', 'chris', 'kaiser', 'chad', 'myers', 'brenda', 'andrews', 'charles', 'boone', 'atsushi', 'tero', 'seiji', 'takagi', 'tetsu', 'saigusa', 'kentaro', 'ito', 'dan', 'bebber', 'mark', 'fricker', 'kenji', 'yumiki', 'ryo', 'kobayashi', 'toshiyuki', 'nakagaki', 'rajesh', 'ganapathy', 'buckley', 'sharon', 'gerbode', 'itai', 'cohen', 'eyal', 'rotenberg', 'yakir', 'pennisi', 'zen', 'faulkes', 'cyrus', 'safinya', 'youli', 'terry', 'harrison', 'zenghui', 'wang', 'jiang', 'wei', 'morse', 'gregory', 'dash', 'oscar', 'vilches', 'cobden', 'christina', 'ann', 'gibbons', 'felicity', 'alcock', 'abigail', 'clements', 'chaille', 'webb', 'trevor', 'lithgow', 'frederic', 'geissmann', 'markus', 'manz', 'steffen', 'jung', 'sieweke', 'miriam', 'merad', 'klaus', 'ley', 'ehre', 'etay', 'lavert', 'meir', 'lahav', 'igor', 'lubomirsky', 'dalin', 'shi', 'xu', 'brian', 'hopkinson', 'fran', 'ois', 'morel', 'peng', 'ge', 'jun', 'tsao', 'stan', 'schein', 'todd', 'green', 'ming', 'luo', 'hong', 'zhou', 'smith', 'justin', 'okano', 'kahn', 'erin', 'bodine', 'sally', 'blower', 'magda', 'claeys', 'gebisa', 'ejeta', 'adrian', 'cho', 'eli', 'kintisch', 'timothy', 'searchinger', 'steven', 'hamburg', 'jerry', 'melillo', 'william', 'chameides', 'petr', 'havlik', 'kammen', 'gene', 'obersteiner', 'oppenheimer', 'robertson', 'tilman', 'ruben', 'lub ...

# %%
json_index['institutionWords'] = {}
for name in json_index['institution'].keys():
    for word in re.sub('[^a-z]',' ',name.lower()).split():
        if not word: continue
        if len(word) <2 or word in stop_words : continue
        if word in json_index['institutionWords']:
            json_index['institutionWords'][word.lower()].append(name)
        else:
            json_index['institutionWords'][word.lower()] = [name]

# %%
json_index['textWords'] = {}
for paper in papers:
    text = paper['text']
    for word in re.sub('[^a-z]',' ',text.lower()).split():
        if not word: continue
        if word in stop_words: continue
        if word in json_index['textWords']:
            json_index['textWords'][word].append(paper['id'])
        else:
            json_index['textWords'][word] = [ paper['id']]

# %%
stop_words = set(stopwords.words('english'))

# %%
len(json_index['textWords'])
# Out:
# 91490

# %%
json_index['titleWords'] = {}
for paper in papers:
    text = paper['title']
    for word in re.sub('[^a-z]',' ',text.lower()).split():
        if not word: continue
        if word in stop_words: continue
        if word in json_index['titleWords']:
            json_index['titleWords'][word].append(paper['id'])
        else:
            json_index['titleWords'][word] = [ paper['id']]

# %%
len(json_index['titleWords'])
# Out:
# 7545

# %%
json_index['publisherWords'] = {}
for paper in papers:
    text = paper['publisher']
    for word in re.sub('[^a-z]',' ',text.lower()).split():
        if not word: continue
        if word in stop_words: continue
        if word in json_index['publisherWords']:
            json_index['publisherWords'][word].append(paper['id'])
        else:
            json_index['publisherWords'][word] = [ paper['id']]

# %%
papers[0].keys()
# Out:
# dict_keys(['category', 'type', 'title', 'author', 'authorInstitution', 'publisher', 'date', 'doi', 'textLink', 'text', 'pdfLink', 'id'])

# %%
json_index.keys()
# Out:
# dict_keys(['category', 'type', 'publisher', 'author', 'institution', 'year', 'authorWords', 'institutionWords', 'textWords', 'titleWords', 'publisherWords'])

# %%
json_index['id'] = {}
for paper in papers:
    idx = paper['id']
    del paper['id']
    json_index['id'][idx] =paper

# %%
papers = []
idx = 0
for year in p:
    for week in p[year]:
        for paper in p[year][week]:
            paper['id'] = idx
            idx+=1
            papers.append(paper)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-218685730891> in <module>()
#       4     for week in p[year]:
#       5         for paper in p[year][week]:
# ----> 6             paper['id'] = idx
#       7             idx+=1
#       8             papers.append(paper)
#
# TypeError: 'int' object does not support item assignment

# %%
json_index['id'][0]
# Out:
# {'category': 'None',
#  'type': 'Other',
#  'title': 'New Products',
#  'author': [],
#  'authorInstitution': [],
#  'publisher': 'American Association for the Advancement of Science',
#  'date': '2010/01/01',
#  'doi': '10.1126/science.327.5961.100-a',
#  'textLink': '/content/327/5961/100.1.full.txt',
#  'text': 'The MaxDiscovery Toxicity Assay Kits monitor in vivo toxicity by measuring liver and heart function in serum samples. These simple and convenient tests allow the rapid, colorimetirc determination of well-characterized functional markers of liver and heart toxicity. They can be used to monitor toxic effects caused by administration of small-interfering RNA, DNA plasmids, transfection agents, or other therapeutic treatments during preclinical studies. The assays can be used in a range of mammals, including mice and rats, providing a powerful tool to assess and reduce the toxicity of drug formulations and to improve drug delivery methods.  Bioo Scientific  For info: 512-707-8993 www.biooscientific.com The Protein Fractionation Kit enables the stepwise separation and preparation of cytoplasmic, membrane, nuclear soluble, chromatin-bound, and cytoskeletal protein extracts from mammalian cultured cells or tissue for protein localization studies or enrichment of specific cellular compartments. The simple protocol is completed in less than three hours and requires no ultracentrifugation over gradients during any of the steps. The subcellular extracts obtained are compatible with a variety of downstream applications, including protein assays, protein immunoblotting, electrophoretic mobility assays, and enzyme activity assays. The kit includes four extraction buffers, a stabilized nuclease, and the Halt Protease Inhibitor Cocktail.  Thermo Fisher Scientific  For info: 815-968-0747 www.thermo.com/pierce Gyrolab xP is a second generation of a platform for miniaturized protein quantification at all stages of drug development. The system offers enhanced ease-of-use,21 CFR part 11 compliance, and extended validation support for smooth implementation in good laboratory practice–regulated environments.  Gyros  For info: +46-18-56-64-00 www.gyros.com The AllostericProfiler service is aimed at researchers developing new drugs using G-protein coupled receptors (GPCRs). The service provides drug developers with cell-based assays to evaluate the functional selectivity of drugs against GPCRs. Although 40 percent of all marketed drugs are targeted to GPCRs, the similarity of GPCR binding sites coupled with saturated intellectual property around this chemical space have hampered GPCR drug discovery efforts. Increasingly, drug makers are instead focusing on novel allosteric GPCR sites to open up new chemical spaces, and this service is designed to help in that effort. The service allows researchers to screen the selectivity of their allosteric compounds for more than 150 GPCRs. Millipore can also provide custom services to help researchers identify new positive allosteric modulators of a GPCR target of interest.  Millipore  For info: 800-548-7853 www.millipore.com/gpcr The AutoloopPRO is a fully automatic carousel for flame sterilizing inoculation loops. The stable housing of the AutoloopPRO enables comfortable and easy access to inoculation loops. Removal positions on both sides make the carousel equally suitable for right- and left-handers. It can be used with up to four inoculation loops. Flaming and cooling time can be adjusted to the second. The carousel rotates and controls flaming automatically. It is fabricated of stainless steel and anodized aluminum and features a graphic display protected by heat-resistant glass.  WLD-TEC  For info: +49-(0)-551-793789 www.WLD-TEC.com The Stacis FP active vibration cancellation floor platform system is designed for use with scanning electron microscopes (SEMs). It features subhertz vibration cancellation in an active hard-mount floor platform that fits most commercial SEMs. SEMs generally incorporate an internal vibration isolation system, and Stacis FP is compatible with all of them. The system is only seven inches tall, measures three inches by 40 inches, weighs less than 400 pounds, and can support 2,500 pounds or more with no soft air suspension. It is available with three or six degrees of free ...
#  'pdfLink': 'http://science.sciencemag.org/content/327/5961/100.1.full.pdf'}

# %%
with open('../data/json/metadata.json','w',encoding='utf-8') as json_file:
    json.dump(json_index, json_file)

# %%
with open("../data/json/metadata.json",'r',encoding='utf-8') as json_file:
    p = json.load(json_file)

# %%
json_index.keys()
# Out:
# dict_keys(['category', 'type', 'publisher', 'author', 'institution', 'year', 'authorWords', 'institutionWords', 'textWords', 'titleWords', 'publisherWords', 'id', 'authorInstitution'])

# %%
import requests
requests.put('https://inf551-project-f33cc.firebaseio.com/metadata.json', json.dumps(json_index))

# %%
for s in ['category', 'type', 'publisher', 'author', 'institution', 'year', 'authorWords', 'institutionWords', 'textWords', 'titleWords', 'publisherWords']:
    for word in json_index[s].keys():
        if re.findall('[^a-zA-Z0-9 ]',word):
            print( word)
# Out:
# Editors' Choice

# %%
re.findall('[^a-z]','pedro')
# Out:
# []

# %%
requests.get('https://inf551-project-f33cc.firebaseio.com/author.json').json()
# Out:
# {' additional authors': [3432],
#  ' genomes project consortium': [877],
#  'a a high': [2362],
#  'a a nugroho': [1006],
#  'a a stark': [3904],
#  'a a watson': [3488],
#  'a aab': [3488],
#  'a aharoni': [1609],
#  'a alczar de velasco': [2041],
#  'a almela': [3488],
#  'a antonelli': [496],
#  'a aranburu': [2041],
#  'a bac sequencing and assembly': [3881],
#  'a balaceanu': [3488],
#  'a barbieri': [3678],
#  'a barnun': [2417],
#  'a beelen': [400],
#  'a beynaghi': [2959],
#  'a bieler': [2417],
#  'a blain': [400],
#  'a blanco': [2298, 3488],
#  'a boehle': [1209],
#  'a bonmat': [2041],
#  'a bovy': [1609],
#  'a bowman': [1520],
#  'a bridgeman': [3488],
#  'a bueno': [3488],
#  'a buschiazzo': [2528],
#  'a c cummings': [1606],
#  'a c fauth': [3488],
#  'a c lees': [2207],
#  'a c rovero': [3488],
#  'a cancio': [3488],
#  'a carrington': [1078],
#  'a carvalho': [2998],
#  'a castellina': [3488],
#  'a catherine markham': [3625],
#  'a cava': [400],
#  'a cavalleri': [3633],
#  'a centeno': [2042],
#  'a chainani': [1176],
#  'a chandra': [3258],
#  'a chilkoti': [1158],
#  'a ciardi': [2190],
#  'a cicchetti': [2298],
#  'a cobos': [3488],
#  'a coleman': [3488],
#  'a cooray': [400],
#  'a coradini': [2298],
#  'a corsi': [3603],
#  'a cousin': [1692, 1843],
#  'a crida': [1273],
#  'a cucchiara': [708],
#  'a d celiz': [3421],
#  'a d lemly': [17],
#  'a d ludlow': [1684],
#  'a d lyerly': [3714],
#  'a d m e osterhaus': [2457],
#  'a d stern': [3258],
#  'a d supanitsky': [3488],
#  'a dafoe': [2516],
#  'a dariush': [400],
#  'a david mcguire': [3088],
#  'a de guibert': [2777],
#  'a de ugarte postigo': [708],
#  'a dekel': [2431],
#  'a demortire': [2794],
#  'a di matteo': [3488],
#  'a douglas stone': [533],
#  'a dundovic': [3488],
#  'a dutton': [2536],
#  'a e carlson': [2536],
#  'a e dessler': [451],
#  'a e fraser': [1397],
#  'a e gleason': [1720],
#  'a e herve': [3488],
#  'a e romashkin': [3727],
#  'a eriksson': [2663],
#  'a etchegoyen': [3488],
#  'a f grillo': [3488],
#  'a f mckenna': [299],
#  'a f vinas': [3903],
#  'a fatih atik': [1399],
#  'a fernndez bremauntz': [833],
#  'a fhlisch': [1420],
#  'a filipi': [3488],
#  'a fledelalon': [64],
#  'a foley': [1578],
#  'a frank': [2190],
#  'a frigeri': [2298, 3232],
#  'a fuenzalida': [2144],
#  'a fuster': [3488],
#  'a g chavez': [3488],
#  'a g fairn': [1844, 3351],
#  'a g mariazzi': [3488],
#  'a gandman': [2259],
#  'a gherghellascu': [3488],
#  'a ghosh': [1844],
#  'a ginebreda': [1914],
#  'a gmezolivencia': [2041],
#  'a gorgi': [3488],
#  'a graciatllez': [2041],
#  'a gruverman': [964, 2615],
#  'a guggenmos': [3470],
#  'a h brand': [3710],
#  'a h castro neto': [2998],
#  'a h goldstein': [1164, 1638],
#  'a h gonzalez': [3904],
#  'a h knoll': [1844],
#  'a h treiman': [1843],
#  'a h wong': [3854],
#  'a hall': [3854],
#  'a haungs': [3488],
#  'a higginbotham': [1720],
#  'a horesh': [3603],
#  'a i f stewart': [2663],
#  'a i fernndezdomnguez': [1158],
#  'a i harris': [400],
#  'a i ortega': [2041],
#  'a ijiri': [2555],
#  'a insolia': [3488],
#  'a inutsuka': [2955],
#  'a iyo': [1176],
#  'a j achkar': [2778],
#  'a j baker': [400],
#  'a j bhide': [1609],
#  'a j castrotirado': [708],
#  'a j cook': [2984],
#  'a j levan': [708],
#  'a j long': [2536],
#  'a j mark hewison': [3625],
#  'a j prenni': [337],
#  'a j romanowsky': [708],
#  'a j sabnis': [3899],
#  'a j van der horst': [708],
#  'a jambon': [1253],
#  'a jameson': [1595],
#  'a jckel': [2417],
#  'a john iafrate': [2267, 3277],
#  'a k geim': [887, 2738, 2821],
#  'a kamble': [708],
#  'a karolina palucka': [1338],
#  'a khayat': [2416],
#  'a korth': [2417],
#  'a kp': [3488],
#  'a kraut': [2516],
#  'a kuotb awad': [3488],
#  'a l cavalieri': [245],
#  'a l goodman': [3678],
#  'a l king': [1152],
#  'a l mller': [3488],
#  'a l sessions': [2214],
#  'a l zerkle': [3727],
#  'a leo iniguez': [473],
#  'a lepland': [3727],
#  'a letessierselvon': [3488],
#  'a leventer': [2157],
#  'a li': [3565],
#  'a lima': [2207],
#  'a lin': [3135],
#  'a longobardo': [2298, 3232],
#  'a lpez casado': [3488],
#  'a lucero': [3488],
#  'a luckman': [2984],
#  'a lupia': [2516, 3447],
#  'a m azzeer': [245],
#  'a m badescu': [3488],
#  'a m botti': [3488],
#  'a m earl': [3767],
#  'a m friedlander': [2535],
#  'a m ghez': [1209],
#  'a m gopstein': [1878],
#  'a m kaufman': [2084],
#  'a m michalak': [3422],
#  'a m ollila': [1843],
#  'a m piotrowski': [3000],
#  'a m rey': [1636, 2084],
#  'a m thurnherr': [2535],
#  'a m van den berg': [3488],
#  'a manrai': [3447],
#  'a manzi': [337],
#  'a marchais': [1721],
#  'a martnezgarca': [1430],
#  'a menshikov': [3488],
#  'a metcalferoach': [3854],
#  'a mezzacappa': [1692],
#  'a mgelhj': [1420],
#  'a miakowski': [3488],
#  'a mishchenko': [887, 2738, 2998],
#  'a mitchell': [3899],
#  'a moore': [2595],
#  'a mora': [496],
#  'a moulet': [3470],
#  'a n grigorenko': [2738],
#  'a n meckler': [1060],
#  'a n morgan': [708],
#  'a n morozovska': [2449],
#  'a nagy': [2663],
#  'a nilsson': [1420],
#  'a olinto': [3488],
#  'a ollila': [1692],
#  'a omont': [400],
#  'a p giri': [1609],
#  'a p walker': [3209],
#  'a pablos': [2041],
#  'a pantojaprez': [2041],
#  'a parra': [3488],
#  'a peng': [288],
#  'a pesquera': [2042],
#  'a peter kershaw': [942],
#  'a physical mapping and bac sequencing': [3881],
#  'a physical mapping bac sequencing assembly and annotation': [3881],
#  'a porcarcastell': [3503],
#  'a portelli': [2390],
#  'a posner': [1543],
#  'a possenti': [1595],
#  'a principi': [2821],
#  'a r brandt': [1878],
#  'a r konicek': [2401],
#  'a r perry': [838],
#  'a r prave': [3727],
#  'a r vasavada': [3351],
#  'a rahmati': [2663],
#  'a raponi': [2298, 3232],
#  'a renzini': [2431],
#  'a revcolevschi': [2778],
#  'a rick horwitz': [2134],
#  'a robotham': [400],
#  'a rodriguez': [3280],
#  'a roy thurik': [1579],
#  'a s fruchter': [708],
#  'a s grandy': [3501],
#  'a s zibrov': [1554, 2362],
#  'a safira': [2362],
#  'a saftoiu': [3488],
#  'a saleh': [3488],
#  'a sanchezmeseguer': [496],
#  'a scheuerlein': [564],
#  'a schulz': [3488],
#  'a segreto': [3488],
#  'a semery': [2298],
#  'a shadkam': [3488],
#  'a shapley': [2431],
#  'a soloviev': [2190],
#  'a sophia gayek': [1730],
#  'a stephen k hashmi': [1296],
#  'a stiepen': [2663],
#  'a taboada': [3488],
#  'a tapia': [3488],
#  'a thomas look': [2260],
#  'a tokunaga': [2416],
#  'a tomadin': [2821],
#  'a v akimov': [1554],
#  'a v gorshkov': [1636],
#  'a v turchyn': [3727],
#  'a van vliet': [3488],
#  'a vasavada': [1843],
#  'a verchovsky': [1253],
#  'a verma': [400],
#  'a w rollins': [1164],
#  'a weberbargioni': [1284],
#  'a wei': [3904],
#  'a weindl': [3488],
#  'a y borisevich': [2449],
#  'a y hoekstra': [2561],
#  'a y nikitin': [2042],
#  'a y q ho': [3603],
#  'a yamanaka': [2955],
#  'a yingst': [1692],
#  'a yu naumov': [3643],
#  'a yushkov': [3488],
#  'a zawadzki': [2221],
#  'a zepeda': [3488],
#  'a zgr yazaydin': [277],
#  'a zurutuza': [2042],
#  'aage k o alstrup': [3920],
#  'aarno palotie': [1579],
#  'aaron c greenville': [3056],
#  'aaron d blackwell': [2693],
#  'aaron d franklin': [2574],
#  'aaron d gitler': [1101, 3013],
#  'aaron j windsor': [1159],
#  'aaron m bauer': [183],
#  'aaron m newman': [1621],
#  'aaron odea': [2451],
#  'aaron r dinner': [2670],
#  'aaron roan': [2831],
#  'aaron s kesselheim': [1092, 3455],
#  'aaron s mansfield': [3659],
#  'aaron shugar': [3132],
#  'aaron steele': [2276],
#  'aaron t fisk': [2497],
#  'aaron t kuan': [2242],
#  'aashiq h kachroo': [2467],
#  'aashish joshi': [500],
#  'abbas ourmazd': [2907],
#  'abby f dernburg': [473],
#  'abdel abdellaoui': [1579],
#  'abdelhafid bendahmane': [3881],
#  'abdelmouhcine gannoun': [966],
#  'abderrahman khila': [3522],
#  'abdulaziz a alkhedhairy': [898],
#  'abdullah al shafi majumder': [2833],
#  'abdullahi h ali': [3625],
#  'abhaya k datye': [3177, 3593],
#  'abigail barr': [275],
#  'abigail clements': [48],
#  'abigail g doyle': [2091],
#  'abigail manson mcguire': [2586],
#  'abigail rabinowitz': [471],
#  'abigail s tucker': [1434],
#  'abraham korol': [3881, 3881, 3881],
#  'abraham l newman': [2307],
#  'abraham loeb': [2712],
#  'abraham q kohrman': [3725],
#  'abram l falk': [3443],
#  'achal k srivastava': [3605],
#  'achim brauer': [748, 1229],
#  'achim j kopf': [3374],
#  'achim mller': [578],
#  'ad van der avoird': [2680],
#  'ad wiebenga': [750],
#  'adam b jaffe': [1983],
#  'adam b weiner': [2341],
#  'adam boulton': [2337],
#  'adam c maloof': [99],
#  'adam c martiny': [2671],
#  'adam d durbin': [2260],
#  'adam e bourassa': [1369],
#  'adam e cohen': [613],
#  'adam f wallace': [1658],
#  'adam frankish': [877],
#  'adam g riess': [2361],
#  'adam h marblestone': [1929],
#  'adam hayden': [3687],
#  'adam j luthman': [3916],
#  'adam j r kent': [3373],
#  'adam kane': [3625],
#  'adam kuspa': [3853],
#  'adam lampert': [2020],
#  'adam m scheer': [1461],
#  'adam mann': [3820],
#  'adam p arkin': [428],
#  'adam r brandt': [3829],
#  'adam s butterworth': [2833],
#  'adam s crystal': [2267],
#  'adam t ford': [3625],
#  'adam w tsen': [1042],
#  'adam z weitemier': [3644],
#  'adamandia kapopoulou': [1475],
#  'adel al jord': [3546],
#  'adele de ninno': [2694],
#  'adele m snowman': [3736],
#  'adeline cathala': [1821],
#  'adi zitrin': [2361],
#  'adiilah mamodecassim': [3594],
#  'adina paytan': [3891],
#  'adina weinberger': [2754],
#  'aditi deshpande': [3560],
#  'aditya d mohite': [2313],
#  'adle hilico': [3169],
#  'admar verschoor': [1499],
#  'adolfo garcasastre': [1635],
#  'adriaan hofman': [1579],
#  'adrian alder': [929],
#  'adrian blescu': [2948],
#  'adrian c lo': [1535],
#  'adrian carr': [473],
#  'adrian cho': [58,
#   178,
#   236,
#   593,
#   607,
#   616,
#   641,
#   740,
#   844,
#   906,
#   985,
#   1037,
#   1222,
#   1695,
#   1755,
#   1766,
#   1825,
#   1855,
#   1875,
#   1889,
#   2001,
#   2013,
#   2038,
#   2165,
#   2435,
#   2481,
#   2639,
#   2797,
#   2798,
#   3220,
#   3385,
#   3391,
#   3460,
#   3559,
#   3661,
#   3679,
#   3907],
#  'adrian j clark': [1615],
#  'adrian treves': [874],
#  'adrian woolfson': [3123],
#  'adriana alberti': [2077, 3881],
#  'adriana heguy': [1218],
#  'adriana machlicova': [1180],
#  'adriana ortizlopez': [2586],
#  'adriana tami': [3628],
#  'adriana yurika maeda': [2883],
#  'adriano fontana': [2361],
#  'adrianus c m boon': [3428],
#  'adrianus j bakermans': [3941],
#  'adrien debry': [1322],
#  'adrienne m luoma': [3651],
#  'ady stern': [1402],
#  'afidalina tumian': [68],
#  'afsaneh eslami': [2351],
#  'aftab a ansari': [3089],
#  'agegnehu gettie': [1917],
#  'agne petrosiute': [2992],
#  'agnel sfeir': [125],
#  'agnes viale': [1218],
#  'agnes waliczek': [408],
#  'agnieszka gauszka': [2744],
#  'agnieszka jaronbecker': [1059, 2711],
#  'agnieszka sergiel': [3625],
#  'agnieszka zienkiewicz': [3594],
#  'agustin cardona': [409],
#  'ahin k zdemir': [3667],
#  'ahmad m n alhendi': [2351],
#  'ahmad n nabhan': [3676],
#  'ahmed kirmani': [1818],
#  'ahmed m mahmoud': [3254],
#  'ahmed mushfiq mobarak': [2466],
#  'ahmed waqas': [2842],
#  'ahmet okay caglayan': [1399],
#  'ahren w jasper': [2247],
#  'aicha gharbiayachi': [463],
#  'aida flor a de la cruz': [2730],
#  'aida m andrs': [3111],
#  'aidan m c couzens': [3947],
#  'aidin niamir': [3625],
#  'aijun lin': [2787],
#  'ailin lu': [2008],
#  'aimee l boyle': [1497],
#  'aina he': [3751],
#  'aissam ikmi': [3933],
#  'aitaro kato': [2977],
#  'aitor g granja': [850],
#  'ajay mahato': [3881],
#  'ajeet pratap singh': [2159],
#  'ajit b datta': [191],
#  'ajlan al zaki': [1254],
#  'akash arora': [3321],
#  'akbar espaillat': [2939],
#  'akdes serin': [1399],
#  'akemi imaoka': [492],
#  'akemi shibata': [3563],
#  'akemi suzuki': [2883],
#  'akhila parthasarthy': [2029],
#  'akhilesh pandey': [3216],
#  'aki ito': [3604],
#  'aki kortelainen': [1384],
#  'akihiko taguchi': [2670],
#  'akihiro isomura': [1788],
#  'akiko yamajihasegawa': [3594],
#  'akira furusawa': [612],
#  'akira hasegawa': [2351],
#  'akira sawa': [1341],
#  'al barabsi': [3565],
#  'al physical mapping': [3881, 3881],
#  'alain dagher': [1465],
#  'alain destexhe': [344],
#  'alain frigon': [1230],
#  'alain herique': [2557],
#  'alain paquette': [3088],
#  'alain vanderplasschen': [3654],
#  'alain vandorsselaer': [463],
#  'alan b krueger': [3307],
#  'alan cooper': [2009, 2569, 2629],
#  'alan dressler': [2361],
#  'alan e e rogers': [2712],
#  'alan f cowman': [725],
#  'alan f wright': [1579],
#  'alan g hinnebusch': [2474],
#  'alan hastings': [2020],
#  'alan i leshner': [2546],
#  'alan j jacobsen': [1682],
#  'alan k meeker': [726],
#  'alan k soper': [3768],
#  'alan l hutchison': [2670],
#  'alan merk': [2491],
#  'alan r rodrigues': [1553],
#  'alan randall': [2456],
#  'alan robock': [1369],
#  'alan s goldman': [690],
#  'alan saghatelian': [1882],
#  'alan simmons': [1346],
#  'alana l conner': [1921],
#  'alasdair ivens': [452],
#  'alastair c lewis': [3650],
#  'alastair hibbins': [3668],
#  'alba dazrodrguez': [643],
#  'alba de martino': [3144],
#  'albert bensaid': [2739],
#  'albert cupo': [2537],
#  'albert d m e osterhaus': [2739],
#  'albert f carley': [2810],
#  'albert hofman': [1579],
#  'albert jeltsch': [181],
#  'albert k lee': [2120],
#  'albert lai': [2837],
#  'albert polman': [2220],
#  'albert quintana': [1811],
#  'albert s baldwin': [3844],
#  'albert tsao': [1454],
#  'albert v smith': [1579],
#  'albertlszl barabsi': [1712, 2340],
#  'alberto ambrosetti': [2834],
#  'alberto bartesaghi': [2491],
#  'alberto beretta': [1686],
#  'alberto c vitari': [2837],
#  'alberto cagigi': [2849],
#  'alberto cazorla': [1446],
#  'alberto de lozar': [112],
#  'alberto moreno': [2802],
#  'alberto peruzzo': [1246],
#  'alberto rorai': [3312],
#  'alberto roselldez': [664],
#  'alberto stolfi': [289],
#  'alberto v reyes': [736],
#  'alberto velamartn': [3452],
#  'albin sandelin': [2351],
#  'albina y borisevich': [2810],
#  'aldo rustichini': [1579],
#  'aldo steinfeld': [474],
#  'alec heckert': [3850],
#  'alec m wodtke': [2073],
#  'alec r chapman': [1312],
#  'alec solway': [1780],
#  'alejandra ortiz': [3804],
#  'alejandra v contreras': [2036],
#  'alejandro aballay': [637],
#  'alejandro burga': [814],
#  'alejandro castao': [3057],
#  'alejandro cearreta': [2744],
#  'alejandro f schinder': [3110, 3723],
#  'alejandro fernandezmartinez': [1658],
#  'alejandro gutierrez': [2260],
#  'alejandro martnez': [1473],
#  'alejandro ocampo': [2381],
#  'alejandro prada': [3538],
#  'aleksandra sherman': [3518],
#  'aleksandra vojvodic': [2072, 3031],
#  'aleksandrs leitis': [3788],
#  'aleksey e kuznetsov': [151],
#  'alessandra bertassoni': [3625],
#  'alessandra carnevale': [2036],
#  'alessandra dallagnese': [3851],
#  'alessandra fidelis': [2545, 2770],
#  'alessandro achilli': [3782],
#  'alessandro cescatti': [557, 2781, 3798],
#  'alessandro fedrizzi': [1372],
#  'alessandro fortunelli': [3161],
#  'alessandro franchin': [1384],
#  'alessandro galli': [205],
#  'alessandro montanari': [188],
#  'alessandro morbidelli': [3043, 3465],
#  'alessandro mori': [289],
#  'alessandro sette': [2570],
#  'alessandro siviero': [2119],
#  'alessandro sonnenfeld': [2361],
#  'alessandro vercelli': [1966],
#  'alex a pollen': [3586],
#  'alex bittel': [2545],
#  'alex cagan': [3877],
#  'alex chortos': [2650, 3783],
#  'alex de marco': [1639],
#  'alex frano': [1849],
#  'alex h parker': [2848],
#  'alex halliday': [3514],
#  'alex j tucker': [2121],
#  'alex john london': [180, 999],
#  'alex k shalek': [2044],
#  'alex kacelnik': [2985],
#  'alex m ward': [2642],
#  'alex retzker': [3399],
#  'alex sandy pentland': [2411, 2850],
#  'alex sykes': [2392],
#  'alex t kalinka': [2805],
#  'alex wellerstein': [2591],
#  'alex wright': [3449],
#  'alex y huang': [2992],
#  'alex zettl': [3775],
#  'alexa fritzsche': [2080],
#  'alexa r stephenson': [3563],
#  'alexander a mironov': [1200],
#  'alexander a puretzky': [3815],
#  'alexander a zibrov': [3708],
#  'alexander abadir': [801],
#  'alexander ako khajetoorians': [661, 1320],
#  'alexander antipenko': [2035],
#  'alexander bolyanatz': [275],
#  'alexander brandis': [3472],
#  'alexander brehm': [3341],
#  'alexander buitrago santanilla': [2277],
#  'alexander c huk': [2858],
#  'alexander c vibrans': [3088],
#  'alexander d diehl': [2351],
#  'alexander d gitlin': [3511],
#  'alexander d johnson': [403, 1710],
#  'alexander deutsch': [188],
#  'alexander e kelly': [363],
#  'alexander eichler': [3761],
#  'alexander f schier': [1012, 1882],
#  'alexander g betz': [461],
#  'alexander g myasnikov': [3954],
#  'alexander gaeta': [1059],
#  'alexander glaser': [2507],
#  'alexander goldshmidt': [771],
#  'alexander goushcha': [2914],
#  'alexander graf': [556],
#  'alexander hexemer': [2129],
#  'alexander i taylor': [980],
#  'alexander j mentzer': [3473],
#  'alexander j p houben': [1474],
#  'alexander jaworski': [2692],
#  'alexander kagansky': [2403],
#  'alexander kiel': [930],
#  'alexander kurilshikov': [2898],
#  'alexander l gaeta': [2711],
#  'alexander leitner': [2428],
#  'alexander lichtenstein': [1320],
#  'alexander lorenz': [1079],
#  'alexander lorestani': [825],
#  'alexander m van der bliek': [1157],
#  'alexander macmillan': [3136],
#  'alexander mironov': [1200],
#  'alexander morozov': [3266],
#  'alexander n krot': [1247],
#  'alexander p fields': [2360],
#  'alexander p wolfe': [2744],
#  'alexander popov': [3318, 3360],
#  'alexander rothenberger': [2312],
#  'alexander s ecker': [2703],
#  'alexander s konopliv': [1368],
#  'alexander saveliev': [2895],
#  'alexander sczyrba': [782],
#  'alexander spaar': [1200],
#  'alexander sph': [3769],
#  'alexander steppke': [2767],
#  'alexander suh': [2249],
#  'alexander teumer': [1579],
#  'alexander todorov': [1274],
#  'alexander v kildishev': [1419],
#  'alexander van geen': [201, 442, 2110],
#  'alexander van oudenaarden': [968],
#  'alexander volkerling': [3136],
#  'alexander vortmeyer': [1399],
#  'alexander w koch': [2692],
#  'alexander y zhu': [2944],
#  'alexander yulin': [3301],
#  'alexandra boltasseva': [1419],
#  'alexandra grosfeld': [3690],
#  'alexandra h bignell': [877],
#  'alexandra l mcgregor': [2885],
#  'alexandra m e jones': [1863],
#  'alexandra m gade': [515],
#  'alexandra m tayar': [2122],
#  'alexandra navrotsky': [360],
#  'alexandra s grutter': [18],
#  'alexandra sapetschnig': [1123],
#  'alexandra tyukavina': [3914],
#  'alexandra z worden': [3095],
#  'alexandra zhernakova': [2898],
#  'alexandre a lussier': [3716],
#  'alexandre antonelli': [3614],
#  'alexandre charlet': [698],
#  'alexandre iannello': [2404],
#  'alexandre j poulain': [1416],
#  'alexandre reuben': [3472],
#  'alexandre silva': [1831],
#  'alexandre tkatchenko': [2834],
#  'alexandre tokovinine': [3931],
#  'alexandre w bissonfilho': [3234],
#  'alexei a lapkin': [3762],
#  'alexei v filippenko': [9, 2361],
#  'alexei v tkachenko': [2779],
#  'alexej pashkin': [2140],
#  'alexey a gritsenko': [2754],
#  'alexey beletsky': [3881],
#  'alexey fedorov': [2271],
#  'alexey potapov': [2382],
#  'alexey s ladokhin': [2914],
#  'alexey silakov': [1760],
#  'alexey snezhko': [2925],
#  'alexey y nikitin': [3657],
#  'alexis brugre': [827],
#  'alexis maizel': [1833],
#  'alfons k g felice': [2938],
#  'alfonso aguirremuoz': [3304],
#  'alfonso alonso': [3779],
#  'alfonso buil': [3645],
#  'alfonso delgadosalinas': [3057, 3213],
#  'alfonso pardo': [187],
#  'alfred leitenstorfer': [2140],
#  'alfred o hero': [3882],
#  'alfred yergey': [727],
#  'alfredo hidalgomiranda': [2036],
#  'alfredo vargas': [1068],
#  'ali aghajanirefah': [2168],
#  'ali alisaac': [3892],
#  'ali belkacem': [2129],
#  'ali khademhosseini': [3320],
#  'ali khaledinasab': [3303],
#  'ali nahvi': [505],
#  'ali shilatifard': [2945],
#  'ali yazdani': [1849, 3097],
#  'aliaksandr druz': [2918],
#  'alice a tomei': [174],
#  'alice dohnalkova': [3330],
#  'alice louize nunes queiroz': [2883],
#  'alice m milner': [3486],
#  'alice meunier': [3546],
#  'alice t shaw': [2267],
#  'alicia k michael': [3259],
#  'alicia rojas': [3057],
#  'alicia tay': [3359],
#  'alicia v zamudio': [3851],
#  'aliesha garrett': [3013],
#  'alina saiakhova': [1014],
#  'alinor l m chauvenet': [3006],
#  'alireza haghighi': [2585],
#  'alireza marandi': [3118],
#  'alison e white': [3439],
#  'alison galloway': [2895],
#  'alison hayward': [3778],
#  'alison l pidoux': [2403],
#  'alison mccook': [794],
#  'alison p galvani': [1706],
#  'alison p klein': [726, 3659],
#  'alison r frand': [1070],
#  'alissa m dgama': [2636],
#  'alistair j fielding': [2071],
#  'alistair m chalk': [2597],
#  'alistair r r forrest': [2351],
#  'aliyah m weinstein': [3582],
#  'alize gouronnec': [3795],
#  'alka saxena': [2351],
#  'alla berezovskaya': [2260],
#  'alla lapidus': [750],
#  'alla y karpova': [1211],
#  'allan h edelsparre': [3607],
#  'allan h macdonald': [3097],
#  'allan r schmitt': [1041],
#  'allegra a petti': [2900],
#  'allen b white': [1446],
#  'allen gathman': [750],
#  'allen l robinson': [3829],
#  'allen r buskirk': [1317],
#  'allison c billi': [1070],
#  'allison c ostriker': [3240],
#  'allison e rubin': [3373],
#  'allison f dennis': [3941],
#  'allison gale': [1952],
#  'allison perrigo': [3614],
#  'allison ryan': [2418],
#  'allister mcguire': [2650],
#  'allon m klein': [1285],
#  'allyn knox': [697],
#  'allyson l byrd': [2752],
#  'alma rosa olveraluna': [3057],
#  'alon harmelin': [3690],
#  'alon keinan': [1015, 3716],
#  'alva biran': [3067],
#  'alva i strand': [2690],
#  'alvaro h crevenna': [712],
#  'alvaro molinacruz': [1533],
#  'alysia r bryll': [2296],
#  'alyson b courtemanch': [3905],
#  'alyssa r frederick': [3419],
#  'am harri': [1692],
#  'amadeus gladbach': [3136],
#  'amal chandran': [3831],
#  'amal jayakumar': [2490],
#  'amala mahadevan': [1093],
#  'amanda e kroesen': [3933],
#  'amanda j neukirch': [2313],
#  'amanda j zellmer': [3518],
#  'amanda kim nguyen': [2650],
#  'amanda l allred': [2670],
#  'amanda m lea': [749],
#  'amanda r hendrix': [377],
#  'amanda schmidt': [2545],
#  'amanda y chong': [2249],
#  'amartya mukhopadhyay': [3697],
#  'amber leahey': [473],
#  'amber m jonesbrunette': [2961],
#  'ambreaurore josselin': [3881, 3881, 3881],
#  'amelia escolano': [3511],
#  'amelia hankla': [2711],
#  'amelia l ritger': [3852],
#  'amidou ndaiye': [3881],
#  'amina helmi': [2119],
#  'amir feizi': [2176],
#  'amir jina': [3390],
#  'amir karger': [2636],
#  'amir m foudeh': [3783],
#  'amir sheikhi': [3940],
#  'amit etkin': [2737],
#  'amit gaggar': [352],
#  'amit k naskar': [1993],
#  'amit mandoli': [2168],
#  'amit zeisel': [2363],
#  'amitabh sharma': [2340],
#  'amitha sevanthi': [3881],
#  'amlie izaute': [2939],
#  'amlie lescrol': [438],
#  'ammar a javed': [3659],
#  'amnon kohen': [2768],
#  'amos b smith': [2215],
#  'amrita pati': [2010],
#  'amy alabaster': [1533],
#  'amy bernard': [1929],
#  'amy c marschilok': [2289],
#  'amy clement': [2651],
#  'amy e shyer': [1718],
#  'amy hauck newman': [419],
#  'amy hin yan tong': [34],
#  'amy j jak': [958],
#  'amy j wagers': [1990],
#  'amy l mcguire': [357, 3827],
#  'amy m balanoff': [336],
#  'amy n finkelstein': [1840],
#  'amy p patterson': [1393],
#  'amy pallant': [685],
#  'amy townsendsmall': [3829],
#  'amy weintrob': [1455],
#  'amy wolf': [3779],
#  'an zhisheng': [747, 2744],
#  'ana b muozmanchado': [2363],
#  'ana beloqui': [408],
#  'ana caballero': [643],
#  'ana cecilia ribeiro cruz': [2883],
#  'ana christina ravelo': [2271],
#  'ana correia': [3693],
#  'ana de oliveira bueno': [580],
#  'ana i kuehne': [3098],
#  'ana laura de lella ezcurra': [3941],
#  'ana m brown': [2220],
#  'ana maldonadocontreras': [369],
#  'ana maria todea': [578],
#  'ana martn': [3681],
#  'ana miller ter kuile': [2935],
#  'ana p g silva': [3136],
#  'ana pombo': [2351],
#  'ana r correia': [2364],
#  'ana r hernndez': [1285],
#  'anahit minasyan': [205],
#  'anairamiz aranguren b': [3057],
#  'anand minajigi': [2544],
#  'ananda nisalak': [3268],
#  'anant chopra': [2585],
#  'anantha p chandrakasan': [3778],
#  'anastasia baryshnikova': [34],
#  'anastasia yuzhakova': [3360],
#  'anatol kontush': [2833],
#  'anatoli remizov': [2556],
#  'anatoly p derevianko': [3328],
#  'anatoly v zayats': [1473],
#  'and the expedition  scientists': [1474],
#  'anders a bjrk': [1122],
#  'anders bergstrm': [3473],
#  'anders e carlson': [736, 2145],
#  'anders frchjensen': [1122],
#  'anders gtherstrm': [992, 1996],
#  'anders m dale': [958],
#  'anders nilsson': [3769],
#  'anders w sandvik': [2872],
#  'andita newton': [2874],
#  'andr braga junqueira': [3212],
#  'andr canosa': [212],
#  'andr g uitterlinden': [1579],
#  'andr hoelz': [2364],
#  'andr lincoln barroso de magalhes': [2386],
#  'andr lincoln barroso magalhes': [3507],
#  'andr m m sousa': [3563],
#  'andr nussenzweig': [302],
#  'andr r studart': [3692],
#  'andra c dos': [473],
#  'andre berndt': [2650],
#  'andre chiaradia': [3625],
#  'andrea aerts': [750],
#  'andrea al': [1831],
#  'andrea bellini': [3361],
#  'andrea benazzo': [3111],
#  'andrea c ferrari': [2275],
#  'andrea colao': [1818],
#  'andrea corsinotti': [1475],
#  'andrea d thompson': [2673],
#  'andrea dillon': [3616],
#  'andrea f young': [3708],
#  'andrea flack': [3777],
#  'andrea gumiero': [2071],
#  'andrea haegebarth': [106],
#  'andrea j pruijssers': [3285],
#  'andrea lini': [1976],
#  'andrea m cooper': [2570],
#  'andrea marzi': [2444, 2575],
#  'andrea morales': [3592],
#  'andrea musacchio': [358],
#  'andrea pauli': [1882],
#  'andrea piunti': [2945],
#  'andrea raponi': [3030],
#  'andrea rubano': [2349],
#  'andrea sboner': [473],
#  'andrea tucci': [3364],
#  'andrea zappe': [3400],
#  'andreas becker': [1059, 2711],
#  'andreas bruckbauer': [850, 3225],
#  'andreas d baxevanis': [1803],
#  'andreas dahl': [2392],
#  'andreas draguhn': [3696],
#  'andreas hirsch': [3580],
#  'andreas kappler': [2393],
#  'andreas kortenkamp': [3838],
#  'andreas lennartsson': [2351],
#  'andreas lthi': [2835],
#  'andreas m kogelnik': [697],
#  'andreas matouschek': [1139],
#  'andreas mielck': [1579],
#  'andreas mooser': [3566],
#  'andreas ostermann': [2071],
#  'andreas p m weber': [2934],
#  'andreas petri': [21],
#  'andreas rechtsteiner': [473],
#  'andreas reichenbach': [1088],
#  'andreas s tolias': [2703],
#  'andreas schlitzer': [1770, 3359],
#  'andreas schmittner': [2997],
#  'andreas schulzebonhage': [1780],
#  'andreas tittl': [3788],
#  'andreas trk': [94],
#  'andreas trumpp': [2743],
#  'andreas untergasser': [535],
#  'andrei buin': [2312],
#  'andrei cimpian': [3207],
#  'andrei n lupas': [2265],
#  'andrei v krivtsov': [1263],
#  'andrej denisenko': [3400],
#  'andrej susor': [619],
#  'andres e leschziner': [1191],
#  'andres f arrieta': [3692],
#  'andres jaraoseguera': [3950],
#  'andres metspalu': [1579],
#  'andres paucar': [1819],
#  'andres ramirezmartinez': [3302],
#  'andrew a chael': [2712],
#  'andrew b barron': [3284],
#  'andrew b hall': [2276],
#  'andrew b sinson': [2658],
#  'andrew b ward': [2537, 2918],
#  'andrew balmford': [2760, 3296],
#  'andrew burgess': [463],
#  'andrew c adey': [3934],
#  'andrew c heath': [1579],
#  'andrew c irvine': [475],
#  'andrew c oates': [2076],
#  'andrew collins': [1497],
#  'andrew curry': [1944],
#  'andrew d barton': [290],
#  'andrew d czaja': [858],
#  'andrew d farmer': [1348],
#  'andrew d griffiths': [3156],
#  'andrew d johnson': [1962],
#  'andrew d richardson': [557],
#  'andrew d straw': [3640],
#  'andrew delariva': [3593],
#  'andrew dillin': [500],
#  'andrew doyle': [3031],
#  'andrew e allen': [3932],
#  'andrew e armitage': [2258],
#  'andrew f cheng': [2848],
#  'andrew f thompson': [2248],
#  'andrew farrell': [825],
#  'andrew filby': [850, 3877],
#  'andrew g clark': [1015],
#  'andrew g sharpe': [3881, 3881, 3881, 3881, 3881],
#  'andrew g white': [1372],
#  'andrew g zink': [2331],
#  'andrew gale': [186],
#  'andrew gaudet': [2378],
#  'andrew gledhill': [2374],
#  'andrew gonzalez': [679, 3406],
#  'andrew h gaspar': [727],
#  'andrew hector': [386],
#  'andrew hodges': [1085],
#  'andrew i flyak': [3098],
#  'andrew i su': [3433],
#  'andrew j beel': [1046],
#  'andrew j davison': [3654],
#  'andrew j hill': [3934],
#  'andrew j larson': [3779],
#  'andrew j marshall': [386],
#  'andrew j medford': [2072],
#  'andrew j newman': [3585],
#  'andrew j saltarelli': [3200],
#  'andrew j schork': [3645],
#  'andrew j steffl': [377, 2848],
#  'andrew j tatem': [2373],
#  'andrew k sweetman': [268],
#  'andrew kinloch': [352],
#  'andrew l paek': [300],
#  'andrew lawler': [213, 281, 356, 585, 2046, 2482, 2988, 3597],
#  'andrew m allen': [3625],
#  'andrew m penner': [2295],
#  'andrew milner': [186],
#  'andrew mitchell': [1882],
#  'andrew muroyama': [473],
#  'andrew n fitch': [1483],
#  'andrew n french': [217],
#  'andrew p dove': [3733],
#  'andrew p mackenzie': [2822],
#  'andrew p waters': [1530],
#  'andrew r babbin': [2490],
#  'andrew r marshall': [3088],
#  'andrew rasmussen': [2894],
#  'andrew robinson': [2264, 2893, 3167],
#  'andrew s cassidy': [2111],
#  'andrew s herbert': [3098],
#  'andrew s macdonald': [677],
#  ...}
